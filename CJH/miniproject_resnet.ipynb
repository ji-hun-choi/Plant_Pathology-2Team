# %% [markdown]
# - plt 전, 후 추가
# - 이미지 변경 추가
# - 배치사이즈 8로 변경
#     - resnet에서 배치사이즈가 크면 그래픽 메모리 초과가 발생
# - nomalize 삭제
# - 모델 변경
# - auc_ruc 추가

# %%
import torch
import torchvision
import os
from torchsummary import summary
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from tqdm import tqdm
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# - gpu 할당

# %%
from google.colab import drive
drive.mount('/content/drive')
dir = './drive/MyDrive/iTStudy/Deep_Learning/miniProject/model_saved/'
# Out:
# Mounted at /content/drive

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# # 파라미터 설정

# %%
CFG = {
    'IMG_SIZE_W':800, #이미지 사이즈
    'IMG_SIZE_H':1200,
    'EPOCHS':150, #에포크
    'LEARNING_RATE':0.0001, #학습률
    'BATCH_SIZE':4, #배치사이즈
    'SCHEDULER':6,
    'PATIENCE':14
}

# %% [markdown]
# # 데이터 적제

# %%
import gdown
## google drive에서 압축된 dataset download
url = 'https://drive.google.com/uc?id=1e_mqtQxew8bGOwtf1I2JvtlJIQ0CSUU8'
fname = 'plant-pathology.zip'
gdown.download(url, fname, quiet=False)
# !unzip plant-pathology.zip -d plant-pathology
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1e_mqtQxew8bGOwtf1I2JvtlJIQ0CSUU8
# To: /content/plant-pathology.zip
# 100%|██████████| 817M/817M [00:03<00:00, 210MB/s]
# Archive:  plant-pathology.zip
#   inflating: plant-pathology/images/Test_0.jpg
#   inflating: plant-pathology/images/Test_1.jpg
#   inflating: plant-pathology/images/Test_10.jpg
#   inflating: plant-pathology/images/Test_100.jpg
#   inflating: plant-pathology/images/Test_1000.jpg
#   inflating: plant-pathology/images/Test_1001.jpg
#   inflating: plant-pathology/images/Test_1002.jpg
#   inflating: plant-pathology/images/Test_1003.jpg
#   inflating: plant-pathology/images/Test_1004.jpg
#   inflating: plant-pathology/images/Test_1005.jpg
#   inflating: plant-pathology/images/Test_1006.jpg
#   inflating: plant-pathology/images/Test_1007.jpg
#   inflating: plant-pathology/images/Test_1008.jpg
#   inflating: plant-pathology/images/Test_1009.jpg
#   inflating: plant-pathology/images/Test_101.jpg
#   inflating: plant-pathology/images/Test_1010.jpg
#   inflating: plant-pathology/images/Test_1011.jpg
#   inflating: plant-pathology/images/Test_1012.jpg
#   inflating: plant-pathology/images/Test_1013.jpg
#   inflating: plant-pathology/images/Test_1014.jpg
#   inflating: plant-pathology/images/Test_1015.jpg
#   inflating: plant-pathology/images/Test_1016.jpg
#   inflating: plant-pathology/images/Test_1017.jpg
#   inflating: plant-pathology/images/Test_1018.jpg
#   inflating: plant-pathology/images/Test_1019.jpg
#   inflating: plant-pathology/images/Test_102.jpg
#   inflating: plant-pathology/images/Test_1020.jpg
#   inflating: plant-pathology/images/Test_1021.jpg
#   inflating: plant-pathology/images/Test_1022.jpg
#   inflating: plant-pathology/images/Test_1023.jpg
#   inflating: plant-pathology/images/Test_1024.jpg
#   inflating: plant-pathology/images/Test_1025.jpg
#   inflating: plant-pathology/images/Test_1026.jpg
#   inflating: plant-pathology/images/Test_1027.jpg
#   inflating: plant-pathology/images/Test_1028.jpg
#   inflating: plant-pathology/images/Test_1029.jpg
#   inflating: plant-pathology/images/Test_103.jpg
#   inflating: plant-pathology/images/Test_1030.jpg
#   inflating: plant-pathology/images/Test_1031.jpg
#   inflating: plant-pathology/images/Test_1032.jpg
#   inflating: plant-pathology/images/Test_1033.jpg
#   inflating: plant-pathology/images/Test_1034.jpg
#   inflating: plant-pathology/images/Test_1035.jpg
#   inflating: plant-pathology/images/Test_1036.jpg
#   inflating: plant-pathology/images/Test_1037.jpg
#   inflating: plant-pathology/images/Test_1038.jpg
#   inflating: plant-pathology/images/Test_1039.jpg
#   inflating: plant-pathology/images/Test_104.jpg
#   inflating: plant-pathology/images/Test_1040.jpg
#   inflating: plant-pathology/images/Test_1041.jpg
#   inflating: plant-pathology/images/Test_1042.jpg
#   inflating: plant-pathology/images/Test_1043.jpg
#   inflating: plant-pathology/images/Test_1044.jpg
#   inflating: plant-pathology/images/Test_1045.jpg
#   inflating: plant-pathology/images/Test_1046.jpg
#   inflating: plant-pathology/images/Test_1047.jpg
#   inflating: plant-pathology/images/Test_1048.jpg
#   inflating: plant-pathology/images/Test_1049.jpg
#   inflating: plant-pathology/images/Test_105.jpg
#   inflating: plant-pathology/images/Test_1050.jpg
#   inflating: plant-pathology/images/Test_1051.jpg
#   inflating: plant-pathology/images/Test_1052.jpg
#   inflating: plant-pathology/images/Test_1053.jpg
#   inflating: plant-pathology/images/Test_1054.jpg
#   inflating: plant-pathology/images/Test_1055.jpg
#   inflating: plant-pathology/images/Test_1056.jpg
#   inflating: plant-pathology/images/Test_1057.jpg
#   inflating: plant-pathology/images/Test_1058.jpg
#   inflating: plant-pathology/images/Test_1059.jpg
#   inflating: plant-pathology/images/Test_106.jpg
#   inflating: plant-pathology/images/Test_1060.jpg
#   inflating: plant-pathology/images/Test_1061.jpg
#   inflating: plant-pathology/images/Test_1062.jpg
#   inflating: plant-pathology/images/Test_1063.jpg
#   inflating: plant-pathology/images/Test_1064.jpg
#   inflating: plant-pathology/images/Test_1065.jpg
#   inflating: plant-pathology/images/Test_1066.jpg
#   inflating: plant-pathology/images/Test_1067.jpg
#   inflating: plant-pathology/images/Test_1068.jpg
#   inflating: plant-pathology/images/Test_1069.jpg
#   inflating: plant-pathology/images/Test_107.jpg
#   inflating: plant-pathology/images/Test_1070.jpg
#   inflating: plant-pathology/images/Test_1071.jpg
#   inflating: plant-pathology/images/Test_1072.jpg
#   inflating: plant-pathology/images/Test_1073.jpg
#   inflating: plant-pathology/images/Test_1074.jpg
#   inflating: plant-pathology/images/Test_1075.jpg
#   inflating: plant-pathology/images/Test_1076.jpg
#   inflating: plant-pathology/images/Test_1077.jpg
#   inflating: plant-pathology/images/Test_1078.jpg
#   inflating: plant-pathology/images/Test_1079.jpg
#   inflating: plant-pathology/images/Test_108.jpg
#   inflating: plant-pathology/images/Test_1080.jpg
#   inflating: plant-pathology/images/Test_1081.jpg
#   inflating: plant-pathology/images/Test_1082.jpg
#   inflating: plant-pathology/images/Test_1083.jpg
#   inflating: plant-pathology/images/Test_1084.jpg
#   inflating: plant-pathology/images/Test_1085.jpg
#   inflating: plant-pathology/images/Test_1086.jpg
#   inflating: plant-pathology/images/Test_1087.jpg
#   inflating: plant-pathology/images/Test_1088.jpg
#   inflating: plant-pathology/images/Test_1089.jpg
#   inflating: plant-pathology/images/Test_109.jpg
#   inflating: plant-pathology/images/Test_1090.jpg
#   inflating: plant-pathology/images/Test_1091.jpg
#   inflating: plant-pathology/images/Test_1092.jpg
#   inflating: plant-pathology/images/Test_1093.jpg
#   inflating: plant-pathology/images/Test_1094.jpg
#   inflating: plant-pathology/images/Test_1095.jpg
#   inflating: plant-pathology/images/Test_1096.jpg
#   inflating: plant-pathology/images/Test_1097.jpg
#   inflating: plant-pathology/images/Test_1098.jpg
#   inflating: plant-pathology/images/Test_1099.jpg
#   inflating: plant-pathology/images/Test_11.jpg
#   inflating: plant-pathology/images/Test_110.jpg
#   inflating: plant-pathology/images/Test_1100.jpg
#   inflating: plant-pathology/images/Test_1101.jpg
#   inflating: plant-pathology/images/Test_1102.jpg
#   inflating: plant-pathology/images/Test_1103.jpg
#   inflating: plant-pathology/images/Test_1104.jpg
#   inflating: plant-pathology/images/Test_1105.jpg
#   inflating: plant-pathology/images/Test_1106.jpg
#   inflating: plant-pathology/images/Test_1107.jpg
#   inflating: plant-pathology/images/Test_1108.jpg
#   inflating: plant-pathology/images/Test_1109.jpg
#   inflating: plant-pathology/images/Test_111.jpg
#   inflating: plant-pathology/images/Test_1110.jpg
#   inflating: plant-pathology/images/Test_1111.jpg
#   inflating: plant-pathology/images/Test_1112.jpg
#   inflating: plant-pathology/images/Test_1113.jpg
#   inflating: plant-pathology/images/Test_1114.jpg
#   inflating: plant-pathology/images/Test_1115.jpg
#   inflating: plant-pathology/images/Test_1116.jpg
#   inflating: plant-pathology/images/Test_1117.jpg
#   inflating: plant-pathology/images/Test_1118.jpg
#   inflating: plant-pathology/images/Test_1119.jpg
#   inflating: plant-pathology/images/Test_112.jpg
#   inflating: plant-pathology/images/Test_1120.jpg
#   inflating: plant-pathology/images/Test_1121.jpg
#   inflating: plant-pathology/images/Test_1122.jpg
#   inflating: plant-pathology/images/Test_1123.jpg
#   inflating: plant-pathology/images/Test_1124.jpg
#   inflating: plant-pathology/images/Test_1125.jpg
#   inflating: plant-pathology/images/Test_1126.jpg
#   inflating: plant-pathology/images/Test_1127.jpg
#   inflating: plant-pathology/images/Test_1128.jpg
#   inflating: plant-pathology/images/Test_1129.jpg
#   inflating: plant-pathology/images/Test_113.jpg
#   inflating: plant-pathology/images/Test_1130.jpg
#   inflating: plant-pathology/images/Test_1131.jpg
#   inflating: plant-pathology/images/Test_1132.jpg
#   inflating: plant-pathology/images/Test_1133.jpg
#   inflating: plant-pathology/images/Test_1134.jpg
#   inflating: plant-pathology/images/Test_1135.jpg
#   inflating: plant-pathology/images/Test_1136.jpg
#   inflating: plant-pathology/images/Test_1137.jpg
#   inflating: plant-pathology/images/Test_1138.jpg
#   inflating: plant-pathology/images/Test_1139.jpg
#   inflating: plant-pathology/images/Test_114.jpg
#   inflating: plant-pathology/images/Test_1140.jpg
#   inflating: plant-pathology/images/Test_1141.jpg
#   inflating: plant-pathology/images/Test_1142.jpg
#   inflating: plant-pathology/images/Test_1143.jpg
#   inflating: plant-pathology/images/Test_1144.jpg
#   inflating: plant-pathology/images/Test_1145.jpg
#   inflating: plant-pathology/images/Test_1146.jpg
#   inflating: plant-pathology/images/Test_1147.jpg
#   inflating: plant-pathology/images/Test_1148.jpg
#   inflating: plant-pathology/images/Test_1149.jpg
#   inflating: plant-pathology/images/Test_115.jpg
#   inflating: plant-pathology/images/Test_1150.jpg
#   inflating: plant-pathology/images/Test_1151.jpg
#   inflating: plant-pathology/images/Test_1152.jpg
#   inflating: plant-pathology/images/Test_1153.jpg
#   inflating: plant-pathology/images/Test_1154.jpg
#   inflating: plant-pathology/images/Test_1155.jpg
#   inflating: plant-pathology/images/Test_1156.jpg
#   inflating: plant-pathology/images/Test_1157.jpg
#   inflating: plant-pathology/images/Test_1158.jpg
#   inflating: plant-pathology/images/Test_1159.jpg
#   inflating: plant-pathology/images/Test_116.jpg
#   inflating: plant-pathology/images/Test_1160.jpg
#   inflating: plant-pathology/images/Test_1161.jpg
#   inflating: plant-pathology/images/Test_1162.jpg
#   inflating: plant-pathology/images/Test_1163.jpg
#   inflating: plant-pathology/images/Test_1164.jpg
#   inflating: plant-pathology/images/Test_1165.jpg
#   inflating: plant-pathology/images/Test_1166.jpg
#   inflating: plant-pathology/images/Test_1167.jpg
#   inflating: plant-pathology/images/Test_1168.jpg
#   inflating: plant-pathology/images/Test_1169.jpg
#   inflating: plant-pathology/images/Test_117.jpg
#   inflating: plant-pathology/images/Test_1170.jpg
#   inflating: plant-pathology/images/Test_1171.jpg
#   inflating: plant-pathology/images/Test_1172.jpg
#   inflating: plant-pathology/images/Test_1173.jpg
#   inflating: plant-pathology/images/Test_1174.jpg
#   inflating: plant-pathology/images/Test_1175.jpg
#   inflating: plant-pathology/images/Test_1176.jpg
#   inflating: plant-pathology/images/Test_1177.jpg
#   inflating: plant-pathology/images/Test_1178.jpg
#   inflating: plant-pathology/images/Test_1179.jpg
#   inflating: plant-pathology/images/Test_118.jpg
#   inflating: plant-pathology/images/Test_1180.jpg
#   inflating: plant-pathology/images/Test_1181.jpg
#   inflating: plant-pathology/images/Test_1182.jpg
#   inflating: plant-pathology/images/Test_1183.jpg
#   inflating: plant-pathology/images/Test_1184.jpg
#   inflating: plant-pathology/images/Test_1185.jpg
#   inflating: plant-pathology/images/Test_1186.jpg
#   inflating: plant-pathology/images/Test_1187.jpg
#   inflating: plant-pathology/images/Test_1188.jpg
#   inflating: plant-pathology/images/Test_1189.jpg
#   inflating: plant-pathology/images/Test_119.jpg
#   inflating: plant-pathology/images/Test_1190.jpg
#   inflating: plant-pathology/images/Test_1191.jpg
#   inflating: plant-pathology/images/Test_1192.jpg
#   inflating: plant-pathology/images/Test_1193.jpg
#   inflating: plant-pathology/images/Test_1194.jpg
#   inflating: plant-pathology/images/Test_1195.jpg
#   inflating: plant-pathology/images/Test_1196.jpg
#   inflating: plant-pathology/images/Test_1197.jpg
#   inflating: plant-pathology/images/Test_1198.jpg
#   inflating: plant-pathology/images/Test_1199.jpg
#   inflating: plant-pathology/images/Test_12.jpg
#   inflating: plant-pathology/images/Test_120.jpg
#   inflating: plant-pathology/images/Test_1200.jpg
#   inflating: plant-pathology/images/Test_1201.jpg
#   inflating: plant-pathology/images/Test_1202.jpg
#   inflating: plant-pathology/images/Test_1203.jpg
#   inflating: plant-pathology/images/Test_1204.jpg
#   inflating: plant-pathology/images/Test_1205.jpg
#   inflating: plant-pathology/images/Test_1206.jpg
#   inflating: plant-pathology/images/Test_1207.jpg
#   inflating: plant-pathology/images/Test_1208.jpg
#   inflating: plant-pathology/images/Test_1209.jpg
#   inflating: plant-pathology/images/Test_121.jpg
#   inflating: plant-pathology/images/Test_1210.jpg
#   inflating: plant-pathology/images/Test_1211.jpg
#   inflating: plant-pathology/images/Test_1212.jpg
#   inflating: plant-pathology/images/Test_1213.jpg
#   inflating: plant-pathology/images/Test_1214.jpg
#   inflating: plant-pathology/images/Test_1215.jpg
#   inflating: plant-pathology/images/Test_1216.jpg
#   inflating: plant-pathology/images/Test_1217.jpg
#   inflating: plant-pathology/images/Test_1218.jpg
#   inflating: plant-pathology/images/Test_1219.jpg
#   inflating: plant-pathology/images/Test_122.jpg
#   inflating: plant-pathology/images/Test_1220.jpg
#   inflating: plant-pathology/images/Test_1221.jpg
#   inflating: plant-pathology/images/Test_1222.jpg
#   inflating: plant-pathology/images/Test_1223.jpg
#   inflating: plant-pathology/images/Test_1224.jpg
#   inflating: plant-pathology/images/Test_1225.jpg
#   inflating: plant-pathology/images/Test_1226.jpg
#   inflating: plant-pathology/images/Test_1227.jpg
#   inflating: plant-pathology/images/Test_1228.jpg
#   inflating: plant-pathology/images/Test_1229.jpg
#   inflating: plant-pathology/images/Test_123.jpg
#   inflating: plant-pathology/images/Test_1230.jpg
#   inflating: plant-pathology/images/Test_1231.jpg
#   inflating: plant-pathology/images/Test_1232.jpg
#   inflating: plant-pathology/images/Test_1233.jpg
#   inflating: plant-pathology/images/Test_1234.jpg
#   inflating: plant-pathology/images/Test_1235.jpg
#   inflating: plant-pathology/images/Test_1236.jpg
#   inflating: plant-pathology/images/Test_1237.jpg
#   inflating: plant-pathology/images/Test_1238.jpg
#   inflating: plant-pathology/images/Test_1239.jpg
#   inflating: plant-pathology/images/Test_124.jpg
#   inflating: plant-pathology/images/Test_1240.jpg
#   inflating: plant-pathology/images/Test_1241.jpg
#   inflating: plant-pathology/images/Test_1242.jpg
#   inflating: plant-pathology/images/Test_1243.jpg
#   inflating: plant-pathology/images/Test_1244.jpg
#   inflating: plant-pathology/images/Test_1245.jpg
#   inflating: plant-pathology/images/Test_1246.jpg
#   inflating: plant-pathology/images/Test_1247.jpg
#   inflating: plant-pathology/images/Test_1248.jpg
#   inflating: plant-pathology/images/Test_1249.jpg
#   inflating: plant-pathology/images/Test_125.jpg
#   inflating: plant-pathology/images/Test_1250.jpg
#   inflating: plant-pathology/images/Test_1251.jpg
#   inflating: plant-pathology/images/Test_1252.jpg
#   inflating: plant-pathology/images/Test_1253.jpg
#   inflating: plant-pathology/images/Test_1254.jpg
#   inflating: plant-pathology/images/Test_1255.jpg
#   inflating: plant-pathology/images/Test_1256.jpg
#   inflating: plant-pathology/images/Test_1257.jpg
#   inflating: plant-pathology/images/Test_1258.jpg
#   inflating: plant-pathology/images/Test_1259.jpg
#   inflating: plant-pathology/images/Test_126.jpg
#   inflating: plant-pathology/images/Test_1260.jpg
#   inflating: plant-pathology/images/Test_1261.jpg
#   inflating: plant-pathology/images/Test_1262.jpg
#   inflating: plant-pathology/images/Test_1263.jpg
#   inflating: plant-pathology/images/Test_1264.jpg
#   inflating: plant-pathology/images/Test_1265.jpg
#   inflating: plant-pathology/images/Test_1266.jpg
#   inflating: plant-pathology/images/Test_1267.jpg
#   inflating: plant-pathology/images/Test_1268.jpg
#   inflating: plant-pathology/images/Test_1269.jpg
#   inflating: plant-pathology/images/Test_127.jpg
#   inflating: plant-pathology/images/Test_1270.jpg
#   inflating: plant-pathology/images/Test_1271.jpg
#   inflating: plant-pathology/images/Test_1272.jpg
#   inflating: plant-pathology/images/Test_1273.jpg
#   inflating: plant-pathology/images/Test_1274.jpg
#   inflating: plant-pathology/images/Test_1275.jpg
#   inflating: plant-pathology/images/Test_1276.jpg
#   inflating: plant-pathology/images/Test_1277.jpg
#   inflating: plant-pathology/images/Test_1278.jpg
#   inflating: plant-pathology/images/Test_1279.jpg
#   inflating: plant-pathology/images/Test_128.jpg
#   inflating: plant-pathology/images/Test_1280.jpg
#   inflating: plant-pathology/images/Test_1281.jpg
#   inflating: plant-pathology/images/Test_1282.jpg
#   inflating: plant-pathology/images/Test_1283.jpg
#   inflating: plant-pathology/images/Test_1284.jpg
#   inflating: plant-pathology/images/Test_1285.jpg
#   inflating: plant-pathology/images/Test_1286.jpg
#   inflating: plant-pathology/images/Test_1287.jpg
#   inflating: plant-pathology/images/Test_1288.jpg
#   inflating: plant-pathology/images/Test_1289.jpg
#   inflating: plant-pathology/images/Test_129.jpg
#   inflating: plant-pathology/images/Test_1290.jpg
#   inflating: plant-pathology/images/Test_1291.jpg
#   inflating: plant-pathology/images/Test_1292.jpg
#   inflating: plant-pathology/images/Test_1293.jpg
#   inflating: plant-pathology/images/Test_1294.jpg
#   inflating: plant-pathology/images/Test_1295.jpg
#   inflating: plant-pathology/images/Test_1296.jpg
#   inflating: plant-pathology/images/Test_1297.jpg
#   inflating: plant-pathology/images/Test_1298.jpg
#   inflating: plant-pathology/images/Test_1299.jpg
#   inflating: plant-pathology/images/Test_13.jpg
#   inflating: plant-pathology/images/Test_130.jpg
#   inflating: plant-pathology/images/Test_1300.jpg
#   inflating: plant-pathology/images/Test_1301.jpg
#   inflating: plant-pathology/images/Test_1302.jpg
#   inflating: plant-pathology/images/Test_1303.jpg
#   inflating: plant-pathology/images/Test_1304.jpg
#   inflating: plant-pathology/images/Test_1305.jpg
#   inflating: plant-pathology/images/Test_1306.jpg
#   inflating: plant-pathology/images/Test_1307.jpg
#   inflating: plant-pathology/images/Test_1308.jpg
#   inflating: plant-pathology/images/Test_1309.jpg
#   inflating: plant-pathology/images/Test_131.jpg
#   inflating: plant-pathology/images/Test_1310.jpg
#   inflating: plant-pathology/images/Test_1311.jpg
#   inflating: plant-pathology/images/Test_1312.jpg
#   inflating: plant-pathology/images/Test_1313.jpg
#   inflating: plant-pathology/images/Test_1314.jpg
#   inflating: plant-pathology/images/Test_1315.jpg
#   inflating: plant-pathology/images/Test_1316.jpg
#   inflating: plant-pathology/images/Test_1317.jpg
#   inflating: plant-pathology/images/Test_1318.jpg
#   inflating: plant-pathology/images/Test_1319.jpg
#   inflating: plant-pathology/images/Test_132.jpg
#   inflating: plant-pathology/images/Test_1320.jpg
#   inflating: plant-pathology/images/Test_1321.jpg
#   inflating: plant-pathology/images/Test_1322.jpg
#   inflating: plant-pathology/images/Test_1323.jpg
#   inflating: plant-pathology/images/Test_1324.jpg
#   inflating: plant-pathology/images/Test_1325.jpg
#   inflating: plant-pathology/images/Test_1326.jpg
#   inflating: plant-pathology/images/Test_1327.jpg
#   inflating: plant-pathology/images/Test_1328.jpg
#   inflating: plant-pathology/images/Test_1329.jpg
#   inflating: plant-pathology/images/Test_133.jpg
#   inflating: plant-pathology/images/Test_1330.jpg
#   inflating: plant-pathology/images/Test_1331.jpg
#   inflating: plant-pathology/images/Test_1332.jpg
#   inflating: plant-pathology/images/Test_1333.jpg
#   inflating: plant-pathology/images/Test_1334.jpg
#   inflating: plant-pathology/images/Test_1335.jpg
#   inflating: plant-pathology/images/Test_1336.jpg
#   inflating: plant-pathology/images/Test_1337.jpg
#   inflating: plant-pathology/images/Test_1338.jpg
#   inflating: plant-pathology/images/Test_1339.jpg
#   inflating: plant-pathology/images/Test_134.jpg
#   inflating: plant-pathology/images/Test_1340.jpg
#   inflating: plant-pathology/images/Test_1341.jpg
#   inflating: plant-pathology/images/Test_1342.jpg
#   inflating: plant-pathology/images/Test_1343.jpg
#   inflating: plant-pathology/images/Test_1344.jpg
#   inflating: plant-pathology/images/Test_1345.jpg
#   inflating: plant-pathology/images/Test_1346.jpg
#   inflating: plant-pathology/images/Test_1347.jpg
#   inflating: plant-pathology/images/Test_1348.jpg
#   inflating: plant-pathology/images/Test_1349.jpg
#   inflating: plant-pathology/images/Test_135.jpg
#   inflating: plant-pathology/images/Test_1350.jpg
#   inflating: plant-pathology/images/Test_1351.jpg
#   inflating: plant-pathology/images/Test_1352.jpg
#   inflating: plant-pathology/images/Test_1353.jpg
#   inflating: plant-pathology/images/Test_1354.jpg
#   inflating: plant-pathology/images/Test_1355.jpg
#   inflating: plant-pathology/images/Test_1356.jpg
#   inflating: plant-pathology/images/Test_1357.jpg
#   inflating: plant-pathology/images/Test_1358.jpg
#   inflating: plant-pathology/images/Test_1359.jpg
#   inflating: plant-pathology/images/Test_136.jpg
#   inflating: plant-pathology/images/Test_1360.jpg
#   inflating: plant-pathology/images/Test_1361.jpg
#   inflating: plant-pathology/images/Test_1362.jpg
#   inflating: plant-pathology/images/Test_1363.jpg
#   inflating: plant-pathology/images/Test_1364.jpg
#   inflating: plant-pathology/images/Test_1365.jpg
#   inflating: plant-pathology/images/Test_1366.jpg
#   inflating: plant-pathology/images/Test_1367.jpg
#   inflating: plant-pathology/images/Test_1368.jpg
#   inflating: plant-pathology/images/Test_1369.jpg
#   inflating: plant-pathology/images/Test_137.jpg
#   inflating: plant-pathology/images/Test_1370.jpg
#   inflating: plant-pathology/images/Test_1371.jpg
#   inflating: plant-pathology/images/Test_1372.jpg
#   inflating: plant-pathology/images/Test_1373.jpg
#   inflating: plant-pathology/images/Test_1374.jpg
#   inflating: plant-pathology/images/Test_1375.jpg
#   inflating: plant-pathology/images/Test_1376.jpg
#   inflating: plant-pathology/images/Test_1377.jpg
#   inflating: plant-pathology/images/Test_1378.jpg
#   inflating: plant-pathology/images/Test_1379.jpg
#   inflating: plant-pathology/images/Test_138.jpg
#   inflating: plant-pathology/images/Test_1380.jpg
#   inflating: plant-pathology/images/Test_1381.jpg
#   inflating: plant-pathology/images/Test_1382.jpg
#   inflating: plant-pathology/images/Test_1383.jpg
#   inflating: plant-pathology/images/Test_1384.jpg
#   inflating: plant-pathology/images/Test_1385.jpg
#   inflating: plant-pathology/images/Test_1386.jpg
#   inflating: plant-pathology/images/Test_1387.jpg
#   inflating: plant-pathology/images/Test_1388.jpg
#   inflating: plant-pathology/images/Test_1389.jpg
#   inflating: plant-pathology/images/Test_139.jpg
#   inflating: plant-pathology/images/Test_1390.jpg
#   inflating: plant-pathology/images/Test_1391.jpg
#   inflating: plant-pathology/images/Test_1392.jpg
#   inflating: plant-pathology/images/Test_1393.jpg
#   inflating: plant-pathology/images/Test_1394.jpg
#   inflating: plant-pathology/images/Test_1395.jpg
#   inflating: plant-pathology/images/Test_1396.jpg
#   inflating: plant-pathology/images/Test_1397.jpg
#   inflating: plant-pathology/images/Test_1398.jpg
#   inflating: plant-pathology/images/Test_1399.jpg
#   inflating: plant-pathology/images/Test_14.jpg
#   inflating: plant-pathology/images/Test_140.jpg
#   inflating: plant-pathology/images/Test_1400.jpg
#   inflating: plant-pathology/images/Test_1401.jpg
#   inflating: plant-pathology/images/Test_1402.jpg
#   inflating: plant-pathology/images/Test_1403.jpg
#   inflating: plant-pathology/images/Test_1404.jpg
#   inflating: plant-pathology/images/Test_1405.jpg
#   inflating: plant-pathology/images/Test_1406.jpg
#   inflating: plant-pathology/images/Test_1407.jpg
#   inflating: plant-pathology/images/Test_1408.jpg
#   inflating: plant-pathology/images/Test_1409.jpg
#   inflating: plant-pathology/images/Test_141.jpg
#   inflating: plant-pathology/images/Test_1410.jpg
#   inflating: plant-pathology/images/Test_1411.jpg
#   inflating: plant-pathology/images/Test_1412.jpg
#   inflating: plant-pathology/images/Test_1413.jpg
#   inflating: plant-pathology/images/Test_1414.jpg
#   inflating: plant-pathology/images/Test_1415.jpg
#   inflating: plant-pathology/images/Test_1416.jpg
#   inflating: plant-pathology/images/Test_1417.jpg
#   inflating: plant-pathology/images/Test_1418.jpg
#   inflating: plant-pathology/images/Test_1419.jpg
#   inflating: plant-pathology/images/Test_142.jpg
#   inflating: plant-pathology/images/Test_1420.jpg
#   inflating: plant-pathology/images/Test_1421.jpg
#   inflating: plant-pathology/images/Test_1422.jpg
#   inflating: plant-pathology/images/Test_1423.jpg
#   inflating: plant-pathology/images/Test_1424.jpg
#   inflating: plant-pathology/images/Test_1425.jpg
#   inflating: plant-pathology/images/Test_1426.jpg
#   inflating: plant-pathology/images/Test_1427.jpg
#   inflating: plant-pathology/images/Test_1428.jpg
#   inflating: plant-pathology/images/Test_1429.jpg
#   inflating: plant-pathology/images/Test_143.jpg
#   inflating: plant-pathology/images/Test_1430.jpg
#   inflating: plant-pathology/images/Test_1431.jpg
#   inflating: plant-pathology/images/Test_1432.jpg
#   inflating: plant-pathology/images/Test_1433.jpg
#   inflating: plant-pathology/images/Test_1434.jpg
#   inflating: plant-pathology/images/Test_1435.jpg
#   inflating: plant-pathology/images/Test_1436.jpg
#   inflating: plant-pathology/images/Test_1437.jpg
#   inflating: plant-pathology/images/Test_1438.jpg
#   inflating: plant-pathology/images/Test_1439.jpg
#   inflating: plant-pathology/images/Test_144.jpg
#   inflating: plant-pathology/images/Test_1440.jpg
#   inflating: plant-pathology/images/Test_1441.jpg
#   inflating: plant-pathology/images/Test_1442.jpg
#   inflating: plant-pathology/images/Test_1443.jpg
#   inflating: plant-pathology/images/Test_1444.jpg
#   inflating: plant-pathology/images/Test_1445.jpg
#   inflating: plant-pathology/images/Test_1446.jpg
#   inflating: plant-pathology/images/Test_1447.jpg
#   inflating: plant-pathology/images/Test_1448.jpg
#   inflating: plant-pathology/images/Test_1449.jpg
#   inflating: plant-pathology/images/Test_145.jpg
#   inflating: plant-pathology/images/Test_1450.jpg
#   inflating: plant-pathology/images/Test_1451.jpg
#   inflating: plant-pathology/images/Test_1452.jpg
#   inflating: plant-pathology/images/Test_1453.jpg
#   inflating: plant-pathology/images/Test_1454.jpg
#   inflating: plant-pathology/images/Test_1455.jpg
#   inflating: plant-pathology/images/Test_1456.jpg
#   inflating: plant-pathology/images/Test_1457.jpg
#   inflating: plant-pathology/images/Test_1458.jpg
#   inflating: plant-pathology/images/Test_1459.jpg
#   inflating: plant-pathology/images/Test_146.jpg
#   inflating: plant-pathology/images/Test_1460.jpg
#   inflating: plant-pathology/images/Test_1461.jpg
#   inflating: plant-pathology/images/Test_1462.jpg
#   inflating: plant-pathology/images/Test_1463.jpg
#   inflating: plant-pathology/images/Test_1464.jpg
#   inflating: plant-pathology/images/Test_1465.jpg
#   inflating: plant-pathology/images/Test_1466.jpg
#   inflating: plant-pathology/images/Test_1467.jpg
#   inflating: plant-pathology/images/Test_1468.jpg
#   inflating: plant-pathology/images/Test_1469.jpg
#   inflating: plant-pathology/images/Test_147.jpg
#   inflating: plant-pathology/images/Test_1470.jpg
#   inflating: plant-pathology/images/Test_1471.jpg
#   inflating: plant-pathology/images/Test_1472.jpg
#   inflating: plant-pathology/images/Test_1473.jpg
#   inflating: plant-pathology/images/Test_1474.jpg
#   inflating: plant-pathology/images/Test_1475.jpg
#   inflating: plant-pathology/images/Test_1476.jpg
#   inflating: plant-pathology/images/Test_1477.jpg
#   inflating: plant-pathology/images/Test_1478.jpg
#   inflating: plant-pathology/images/Test_1479.jpg
#   inflating: plant-pathology/images/Test_148.jpg
#   inflating: plant-pathology/images/Test_1480.jpg
#   inflating: plant-pathology/images/Test_1481.jpg
#   inflating: plant-pathology/images/Test_1482.jpg
#   inflating: plant-pathology/images/Test_1483.jpg
#   inflating: plant-pathology/images/Test_1484.jpg
#   inflating: plant-pathology/images/Test_1485.jpg
#   inflating: plant-pathology/images/Test_1486.jpg
#   inflating: plant-pathology/images/Test_1487.jpg
#   inflating: plant-pathology/images/Test_1488.jpg
#   inflating: plant-pathology/images/Test_1489.jpg
#   inflating: plant-pathology/images/Test_149.jpg
#   inflating: plant-pathology/images/Test_1490.jpg
#   inflating: plant-pathology/images/Test_1491.jpg
#   inflating: plant-pathology/images/Test_1492.jpg
#   inflating: plant-pathology/images/Test_1493.jpg
#   inflating: plant-pathology/images/Test_1494.jpg
#   inflating: plant-pathology/images/Test_1495.jpg
#   inflating: plant-pathology/images/Test_1496.jpg
#   inflating: plant-pathology/images/Test_1497.jpg
#   inflating: plant-pathology/images/Test_1498.jpg
#   inflating: plant-pathology/images/Test_1499.jpg
#   inflating: plant-pathology/images/Test_15.jpg
#   inflating: plant-pathology/images/Test_150.jpg
#   inflating: plant-pathology/images/Test_1500.jpg
#   inflating: plant-pathology/images/Test_1501.jpg
#   inflating: plant-pathology/images/Test_1502.jpg
#   inflating: plant-pathology/images/Test_1503.jpg
#   inflating: plant-pathology/images/Test_1504.jpg
#   inflating: plant-pathology/images/Test_1505.jpg
#   inflating: plant-pathology/images/Test_1506.jpg
#   inflating: plant-pathology/images/Test_1507.jpg
#   inflating: plant-pathology/images/Test_1508.jpg
#   inflating: plant-pathology/images/Test_1509.jpg
#   inflating: plant-pathology/images/Test_151.jpg
#   inflating: plant-pathology/images/Test_1510.jpg
#   inflating: plant-pathology/images/Test_1511.jpg
#   inflating: plant-pathology/images/Test_1512.jpg
#   inflating: plant-pathology/images/Test_1513.jpg
#   inflating: plant-pathology/images/Test_1514.jpg
#   inflating: plant-pathology/images/Test_1515.jpg
#   inflating: plant-pathology/images/Test_1516.jpg
#   inflating: plant-pathology/images/Test_1517.jpg
#   inflating: plant-pathology/images/Test_1518.jpg
#   inflating: plant-pathology/images/Test_1519.jpg
#   inflating: plant-pathology/images/Test_152.jpg
#   inflating: plant-pathology/images/Test_1520.jpg
#   inflating: plant-pathology/images/Test_1521.jpg
#   inflating: plant-pathology/images/Test_1522.jpg
#   inflating: plant-pathology/images/Test_1523.jpg
#   inflating: plant-pathology/images/Test_1524.jpg
#   inflating: plant-pathology/images/Test_1525.jpg
#   inflating: plant-pathology/images/Test_1526.jpg
#   inflating: plant-pathology/images/Test_1527.jpg
#   inflating: plant-pathology/images/Test_1528.jpg
#   inflating: plant-pathology/images/Test_1529.jpg
#   inflating: plant-pathology/images/Test_153.jpg
#   inflating: plant-pathology/images/Test_1530.jpg
#   inflating: plant-pathology/images/Test_1531.jpg
#   inflating: plant-pathology/images/Test_1532.jpg
#   inflating: plant-pathology/images/Test_1533.jpg
#   inflating: plant-pathology/images/Test_1534.jpg
#   inflating: plant-pathology/images/Test_1535.jpg
#   inflating: plant-pathology/images/Test_1536.jpg
#   inflating: plant-pathology/images/Test_1537.jpg
#   inflating: plant-pathology/images/Test_1538.jpg
#   inflating: plant-pathology/images/Test_1539.jpg
#   inflating: plant-pathology/images/Test_154.jpg
#   inflating: plant-pathology/images/Test_1540.jpg
#   inflating: plant-pathology/images/Test_1541.jpg
#   inflating: plant-pathology/images/Test_1542.jpg
#   inflating: plant-pathology/images/Test_1543.jpg
#   inflating: plant-pathology/images/Test_1544.jpg
#   inflating: plant-pathology/images/Test_1545.jpg
#   inflating: plant-pathology/images/Test_1546.jpg
#   inflating: plant-pathology/images/Test_1547.jpg
#   inflating: plant-pathology/images/Test_1548.jpg
#   inflating: plant-pathology/images/Test_1549.jpg
#   inflating: plant-pathology/images/Test_155.jpg
#   inflating: plant-pathology/images/Test_1550.jpg
#   inflating: plant-pathology/images/Test_1551.jpg
#   inflating: plant-pathology/images/Test_1552.jpg
#   inflating: plant-pathology/images/Test_1553.jpg
#   inflating: plant-pathology/images/Test_1554.jpg
#   inflating: plant-pathology/images/Test_1555.jpg
#   inflating: plant-pathology/images/Test_1556.jpg
#   inflating: plant-pathology/images/Test_1557.jpg
#   inflating: plant-pathology/images/Test_1558.jpg
#   inflating: plant-pathology/images/Test_1559.jpg
#   inflating: plant-pathology/images/Test_156.jpg
#   inflating: plant-pathology/images/Test_1560.jpg
#   inflating: plant-pathology/images/Test_1561.jpg
#   inflating: plant-pathology/images/Test_1562.jpg
#   inflating: plant-pathology/images/Test_1563.jpg
#   inflating: plant-pathology/images/Test_1564.jpg
#   inflating: plant-pathology/images/Test_1565.jpg
#   inflating: plant-pathology/images/Test_1566.jpg
#   inflating: plant-pathology/images/Test_1567.jpg
#   inflating: plant-pathology/images/Test_1568.jpg
#   inflating: plant-pathology/images/Test_1569.jpg
#   inflating: plant-pathology/images/Test_157.jpg
#   inflating: plant-pathology/images/Test_1570.jpg
#   inflating: plant-pathology/images/Test_1571.jpg
#   inflating: plant-pathology/images/Test_1572.jpg
#   inflating: plant-pathology/images/Test_1573.jpg
#   inflating: plant-pathology/images/Test_1574.jpg
#   inflating: plant-pathology/images/Test_1575.jpg
#   inflating: plant-pathology/images/Test_1576.jpg
#   inflating: plant-pathology/images/Test_1577.jpg
#   inflating: plant-pathology/images/Test_1578.jpg
#   inflating: plant-pathology/images/Test_1579.jpg
#   inflating: plant-pathology/images/Test_158.jpg
#   inflating: plant-pathology/images/Test_1580.jpg
#   inflating: plant-pathology/images/Test_1581.jpg
#   inflating: plant-pathology/images/Test_1582.jpg
#   inflating: plant-pathology/images/Test_1583.jpg
#   inflating: plant-pathology/images/Test_1584.jpg
#   inflating: plant-pathology/images/Test_1585.jpg
#   inflating: plant-pathology/images/Test_1586.jpg
#   inflating: plant-pathology/images/Test_1587.jpg
#   inflating: plant-pathology/images/Test_1588.jpg
#   inflating: plant-pathology/images/Test_1589.jpg
#   inflating: plant-pathology/images/Test_159.jpg
#   inflating: plant-pathology/images/Test_1590.jpg
#   inflating: plant-pathology/images/Test_1591.jpg
#   inflating: plant-pathology/images/Test_1592.jpg
#   inflating: plant-pathology/images/Test_1593.jpg
#   inflating: plant-pathology/images/Test_1594.jpg
#   inflating: plant-pathology/images/Test_1595.jpg
#   inflating: plant-pathology/images/Test_1596.jpg
#   inflating: plant-pathology/images/Test_1597.jpg
#   inflating: plant-pathology/images/Test_1598.jpg
#   inflating: plant-pathology/images/Test_1599.jpg
#   inflating: plant-pathology/images/Test_16.jpg
#   inflating: plant-pathology/images/Test_160.jpg
#   inflating: plant-pathology/images/Test_1600.jpg
#   inflating: plant-pathology/images/Test_1601.jpg
#   inflating: plant-pathology/images/Test_1602.jpg
#   inflating: plant-pathology/images/Test_1603.jpg
#   inflating: plant-pathology/images/Test_1604.jpg
#   inflating: plant-pathology/images/Test_1605.jpg
#   inflating: plant-pathology/images/Test_1606.jpg
#   inflating: plant-pathology/images/Test_1607.jpg
#   inflating: plant-pathology/images/Test_1608.jpg
#   inflating: plant-pathology/images/Test_1609.jpg
#   inflating: plant-pathology/images/Test_161.jpg
#   inflating: plant-pathology/images/Test_1610.jpg
#   inflating: plant-pathology/images/Test_1611.jpg
#   inflating: plant-pathology/images/Test_1612.jpg
#   inflating: plant-pathology/images/Test_1613.jpg
#   inflating: plant-pathology/images/Test_1614.jpg
#   inflating: plant-pathology/images/Test_1615.jpg
#   inflating: plant-pathology/images/Test_1616.jpg
#   inflating: plant-pathology/images/Test_1617.jpg
#   inflating: plant-pathology/images/Test_1618.jpg
#   inflating: plant-pathology/images/Test_1619.jpg
#   inflating: plant-pathology/images/Test_162.jpg
#   inflating: plant-pathology/images/Test_1620.jpg
#   inflating: plant-pathology/images/Test_1621.jpg
#   inflating: plant-pathology/images/Test_1622.jpg
#   inflating: plant-pathology/images/Test_1623.jpg
#   inflating: plant-pathology/images/Test_1624.jpg
#   inflating: plant-pathology/images/Test_1625.jpg
#   inflating: plant-pathology/images/Test_1626.jpg
#   inflating: plant-pathology/images/Test_1627.jpg
#   inflating: plant-pathology/images/Test_1628.jpg
#   inflating: plant-pathology/images/Test_1629.jpg
#   inflating: plant-pathology/images/Test_163.jpg
#   inflating: plant-pathology/images/Test_1630.jpg
#   inflating: plant-pathology/images/Test_1631.jpg
#   inflating: plant-pathology/images/Test_1632.jpg
#   inflating: plant-pathology/images/Test_1633.jpg
#   inflating: plant-pathology/images/Test_1634.jpg
#   inflating: plant-pathology/images/Test_1635.jpg
#   inflating: plant-pathology/images/Test_1636.jpg
#   inflating: plant-pathology/images/Test_1637.jpg
#   inflating: plant-pathology/images/Test_1638.jpg
#   inflating: plant-pathology/images/Test_1639.jpg
#   inflating: plant-pathology/images/Test_164.jpg
#   inflating: plant-pathology/images/Test_1640.jpg
#   inflating: plant-pathology/images/Test_1641.jpg
#   inflating: plant-pathology/images/Test_1642.jpg
#   inflating: plant-pathology/images/Test_1643.jpg
#   inflating: plant-pathology/images/Test_1644.jpg
#   inflating: plant-pathology/images/Test_1645.jpg
#   inflating: plant-pathology/images/Test_1646.jpg
#   inflating: plant-pathology/images/Test_1647.jpg
#   inflating: plant-pathology/images/Test_1648.jpg
#   inflating: plant-pathology/images/Test_1649.jpg
#   inflating: plant-pathology/images/Test_165.jpg
#   inflating: plant-pathology/images/Test_1650.jpg
#   inflating: plant-pathology/images/Test_1651.jpg
#   inflating: plant-pathology/images/Test_1652.jpg
#   inflating: plant-pathology/images/Test_1653.jpg
#   inflating: plant-pathology/images/Test_1654.jpg
#   inflating: plant-pathology/images/Test_1655.jpg
#   inflating: plant-pathology/images/Test_1656.jpg
#   inflating: plant-pathology/images/Test_1657.jpg
#   inflating: plant-pathology/images/Test_1658.jpg
#   inflating: plant-pathology/images/Test_1659.jpg
#   inflating: plant-pathology/images/Test_166.jpg
#   inflating: plant-pathology/images/Test_1660.jpg
#   inflating: plant-pathology/images/Test_1661.jpg
#   inflating: plant-pathology/images/Test_1662.jpg
#   inflating: plant-pathology/images/Test_1663.jpg
#   inflating: plant-pathology/images/Test_1664.jpg
#   inflating: plant-pathology/images/Test_1665.jpg
#   inflating: plant-pathology/images/Test_1666.jpg
#   inflating: plant-pathology/images/Test_1667.jpg
#   inflating: plant-pathology/images/Test_1668.jpg
#   inflating: plant-pathology/images/Test_1669.jpg
#   inflating: plant-pathology/images/Test_167.jpg
#   inflating: plant-pathology/images/Test_1670.jpg
#   inflating: plant-pathology/images/Test_1671.jpg
#   inflating: plant-pathology/images/Test_1672.jpg
#   inflating: plant-pathology/images/Test_1673.jpg
#   inflating: plant-pathology/images/Test_1674.jpg
#   inflating: plant-pathology/images/Test_1675.jpg
#   inflating: plant-pathology/images/Test_1676.jpg
#   inflating: plant-pathology/images/Test_1677.jpg
#   inflating: plant-pathology/images/Test_1678.jpg
#   inflating: plant-pathology/images/Test_1679.jpg
#   inflating: plant-pathology/images/Test_168.jpg
#   inflating: plant-pathology/images/Test_1680.jpg
#   inflating: plant-pathology/images/Test_1681.jpg
#   inflating: plant-pathology/images/Test_1682.jpg
#   inflating: plant-pathology/images/Test_1683.jpg
#   inflating: plant-pathology/images/Test_1684.jpg
#   inflating: plant-pathology/images/Test_1685.jpg
#   inflating: plant-pathology/images/Test_1686.jpg
#   inflating: plant-pathology/images/Test_1687.jpg
#   inflating: plant-pathology/images/Test_1688.jpg
#   inflating: plant-pathology/images/Test_1689.jpg
#   inflating: plant-pathology/images/Test_169.jpg
#   inflating: plant-pathology/images/Test_1690.jpg
#   inflating: plant-pathology/images/Test_1691.jpg
#   inflating: plant-pathology/images/Test_1692.jpg
#   inflating: plant-pathology/images/Test_1693.jpg
#   inflating: plant-pathology/images/Test_1694.jpg
#   inflating: plant-pathology/images/Test_1695.jpg
#   inflating: plant-pathology/images/Test_1696.jpg
#   inflating: plant-pathology/images/Test_1697.jpg
#   inflating: plant-pathology/images/Test_1698.jpg
#   inflating: plant-pathology/images/Test_1699.jpg
#   inflating: plant-pathology/images/Test_17.jpg
#   inflating: plant-pathology/images/Test_170.jpg
#   inflating: plant-pathology/images/Test_1700.jpg
#   inflating: plant-pathology/images/Test_1701.jpg
#   inflating: plant-pathology/images/Test_1702.jpg
#   inflating: plant-pathology/images/Test_1703.jpg
#   inflating: plant-pathology/images/Test_1704.jpg
#   inflating: plant-pathology/images/Test_1705.jpg
#   inflating: plant-pathology/images/Test_1706.jpg
#   inflating: plant-pathology/images/Test_1707.jpg
#   inflating: plant-pathology/images/Test_1708.jpg
#   inflating: plant-pathology/images/Test_1709.jpg
#   inflating: plant-pathology/images/Test_171.jpg
#   inflating: plant-pathology/images/Test_1710.jpg
#   inflating: plant-pathology/images/Test_1711.jpg
#   inflating: plant-pathology/images/Test_1712.jpg
#   inflating: plant-pathology/images/Test_1713.jpg
#   inflating: plant-pathology/images/Test_1714.jpg
#   inflating: plant-pathology/images/Test_1715.jpg
#   inflating: plant-pathology/images/Test_1716.jpg
#   inflating: plant-pathology/images/Test_1717.jpg
#   inflating: plant-pathology/images/Test_1718.jpg
#   inflating: plant-pathology/images/Test_1719.jpg
#   inflating: plant-pathology/images/Test_172.jpg
#   inflating: plant-pathology/images/Test_1720.jpg
#   inflating: plant-pathology/images/Test_1721.jpg
#   inflating: plant-pathology/images/Test_1722.jpg
#   inflating: plant-pathology/images/Test_1723.jpg
#   inflating: plant-pathology/images/Test_1724.jpg
#   inflating: plant-pathology/images/Test_1725.jpg
#   inflating: plant-pathology/images/Test_1726.jpg
#   inflating: plant-pathology/images/Test_1727.jpg
#   inflating: plant-pathology/images/Test_1728.jpg
#   inflating: plant-pathology/images/Test_1729.jpg
#   inflating: plant-pathology/images/Test_173.jpg
#   inflating: plant-pathology/images/Test_1730.jpg
#   inflating: plant-pathology/images/Test_1731.jpg
#   inflating: plant-pathology/images/Test_1732.jpg
#   inflating: plant-pathology/images/Test_1733.jpg
#   inflating: plant-pathology/images/Test_1734.jpg
#   inflating: plant-pathology/images/Test_1735.jpg
#   inflating: plant-pathology/images/Test_1736.jpg
#   inflating: plant-pathology/images/Test_1737.jpg
#   inflating: plant-pathology/images/Test_1738.jpg
#   inflating: plant-pathology/images/Test_1739.jpg
#   inflating: plant-pathology/images/Test_174.jpg
#   inflating: plant-pathology/images/Test_1740.jpg
#   inflating: plant-pathology/images/Test_1741.jpg
#   inflating: plant-pathology/images/Test_1742.jpg
#   inflating: plant-pathology/images/Test_1743.jpg
#   inflating: plant-pathology/images/Test_1744.jpg
#   inflating: plant-pathology/images/Test_1745.jpg
#   inflating: plant-pathology/images/Test_1746.jpg
#   inflating: plant-pathology/images/Test_1747.jpg
#   inflating: plant-pathology/images/Test_1748.jpg
#   inflating: plant-pathology/images/Test_1749.jpg
#   inflating: plant-pathology/images/Test_175.jpg
#   inflating: plant-pathology/images/Test_1750.jpg
#   inflating: plant-pathology/images/Test_1751.jpg
#   inflating: plant-pathology/images/Test_1752.jpg
#   inflating: plant-pathology/images/Test_1753.jpg
#   inflating: plant-pathology/images/Test_1754.jpg
#   inflating: plant-pathology/images/Test_1755.jpg
#   inflating: plant-pathology/images/Test_1756.jpg
#   inflating: plant-pathology/images/Test_1757.jpg
#   inflating: plant-pathology/images/Test_1758.jpg
#   inflating: plant-pathology/images/Test_1759.jpg
#   inflating: plant-pathology/images/Test_176.jpg
#   inflating: plant-pathology/images/Test_1760.jpg
#   inflating: plant-pathology/images/Test_1761.jpg
#   inflating: plant-pathology/images/Test_1762.jpg
#   inflating: plant-pathology/images/Test_1763.jpg
#   inflating: plant-pathology/images/Test_1764.jpg
#   inflating: plant-pathology/images/Test_1765.jpg
#   inflating: plant-pathology/images/Test_1766.jpg
#   inflating: plant-pathology/images/Test_1767.jpg
#   inflating: plant-pathology/images/Test_1768.jpg
#   inflating: plant-pathology/images/Test_1769.jpg
#   inflating: plant-pathology/images/Test_177.jpg
#   inflating: plant-pathology/images/Test_1770.jpg
#   inflating: plant-pathology/images/Test_1771.jpg
#   inflating: plant-pathology/images/Test_1772.jpg
#   inflating: plant-pathology/images/Test_1773.jpg
#   inflating: plant-pathology/images/Test_1774.jpg
#   inflating: plant-pathology/images/Test_1775.jpg
#   inflating: plant-pathology/images/Test_1776.jpg
#   inflating: plant-pathology/images/Test_1777.jpg
#   inflating: plant-pathology/images/Test_1778.jpg
#   inflating: plant-pathology/images/Test_1779.jpg
#   inflating: plant-pathology/images/Test_178.jpg
#   inflating: plant-pathology/images/Test_1780.jpg
#   inflating: plant-pathology/images/Test_1781.jpg
#   inflating: plant-pathology/images/Test_1782.jpg
#   inflating: plant-pathology/images/Test_1783.jpg
#   inflating: plant-pathology/images/Test_1784.jpg
#   inflating: plant-pathology/images/Test_1785.jpg
#   inflating: plant-pathology/images/Test_1786.jpg
#   inflating: plant-pathology/images/Test_1787.jpg
#   inflating: plant-pathology/images/Test_1788.jpg
#   inflating: plant-pathology/images/Test_1789.jpg
#   inflating: plant-pathology/images/Test_179.jpg
#   inflating: plant-pathology/images/Test_1790.jpg
#   inflating: plant-pathology/images/Test_1791.jpg
#   inflating: plant-pathology/images/Test_1792.jpg
#   inflating: plant-pathology/images/Test_1793.jpg
#   inflating: plant-pathology/images/Test_1794.jpg
#   inflating: plant-pathology/images/Test_1795.jpg
#   inflating: plant-pathology/images/Test_1796.jpg
#   inflating: plant-pathology/images/Test_1797.jpg
#   inflating: plant-pathology/images/Test_1798.jpg
#   inflating: plant-pathology/images/Test_1799.jpg
#   inflating: plant-pathology/images/Test_18.jpg
#   inflating: plant-pathology/images/Test_180.jpg
#   inflating: plant-pathology/images/Test_1800.jpg
#   inflating: plant-pathology/images/Test_1801.jpg
#   inflating: plant-pathology/images/Test_1802.jpg
#   inflating: plant-pathology/images/Test_1803.jpg
#   inflating: plant-pathology/images/Test_1804.jpg
#   inflating: plant-pathology/images/Test_1805.jpg
#   inflating: plant-pathology/images/Test_1806.jpg
#   inflating: plant-pathology/images/Test_1807.jpg
#   inflating: plant-pathology/images/Test_1808.jpg
#   inflating: plant-pathology/images/Test_1809.jpg
#   inflating: plant-pathology/images/Test_181.jpg
#   inflating: plant-pathology/images/Test_1810.jpg
#   inflating: plant-pathology/images/Test_1811.jpg
#   inflating: plant-pathology/images/Test_1812.jpg
#   inflating: plant-pathology/images/Test_1813.jpg
#   inflating: plant-pathology/images/Test_1814.jpg
#   inflating: plant-pathology/images/Test_1815.jpg
#   inflating: plant-pathology/images/Test_1816.jpg
#   inflating: plant-pathology/images/Test_1817.jpg
#   inflating: plant-pathology/images/Test_1818.jpg
#   inflating: plant-pathology/images/Test_1819.jpg
#   inflating: plant-pathology/images/Test_182.jpg
#   inflating: plant-pathology/images/Test_1820.jpg
#   inflating: plant-pathology/images/Test_183.jpg
#   inflating: plant-pathology/images/Test_184.jpg
#   inflating: plant-pathology/images/Test_185.jpg
#   inflating: plant-pathology/images/Test_186.jpg
#   inflating: plant-pathology/images/Test_187.jpg
#   inflating: plant-pathology/images/Test_188.jpg
# ...
#   inflating: plant-pathology/images/Train_724.jpg
#   inflating: plant-pathology/images/Train_725.jpg
#   inflating: plant-pathology/images/Train_726.jpg
#   inflating: plant-pathology/images/Train_727.jpg
#   inflating: plant-pathology/images/Train_728.jpg
#   inflating: plant-pathology/images/Train_729.jpg
#   inflating: plant-pathology/images/Train_73.jpg
#   inflating: plant-pathology/images/Train_730.jpg
#   inflating: plant-pathology/images/Train_731.jpg
#   inflating: plant-pathology/images/Train_732.jpg
#   inflating: plant-pathology/images/Train_733.jpg
#   inflating: plant-pathology/images/Train_734.jpg
#   inflating: plant-pathology/images/Train_735.jpg
#   inflating: plant-pathology/images/Train_736.jpg
#   inflating: plant-pathology/images/Train_737.jpg
#   inflating: plant-pathology/images/Train_738.jpg
#   inflating: plant-pathology/images/Train_739.jpg
#   inflating: plant-pathology/images/Train_74.jpg
#   inflating: plant-pathology/images/Train_740.jpg
#   inflating: plant-pathology/images/Train_741.jpg
#   inflating: plant-pathology/images/Train_742.jpg
#   inflating: plant-pathology/images/Train_743.jpg
#   inflating: plant-pathology/images/Train_744.jpg
#   inflating: plant-pathology/images/Train_745.jpg
#   inflating: plant-pathology/images/Train_746.jpg
#   inflating: plant-pathology/images/Train_747.jpg
#   inflating: plant-pathology/images/Train_748.jpg
#   inflating: plant-pathology/images/Train_749.jpg
#   inflating: plant-pathology/images/Train_75.jpg
#   inflating: plant-pathology/images/Train_750.jpg
#   inflating: plant-pathology/images/Train_751.jpg
#   inflating: plant-pathology/images/Train_752.jpg
#   inflating: plant-pathology/images/Train_753.jpg
#   inflating: plant-pathology/images/Train_754.jpg
#   inflating: plant-pathology/images/Train_755.jpg
#   inflating: plant-pathology/images/Train_756.jpg
#   inflating: plant-pathology/images/Train_757.jpg
#   inflating: plant-pathology/images/Train_758.jpg
#   inflating: plant-pathology/images/Train_759.jpg
#   inflating: plant-pathology/images/Train_76.jpg
#   inflating: plant-pathology/images/Train_760.jpg
#   inflating: plant-pathology/images/Train_761.jpg
#   inflating: plant-pathology/images/Train_762.jpg
#   inflating: plant-pathology/images/Train_763.jpg
#   inflating: plant-pathology/images/Train_764.jpg
#   inflating: plant-pathology/images/Train_765.jpg
#   inflating: plant-pathology/images/Train_766.jpg
#   inflating: plant-pathology/images/Train_767.jpg
#   inflating: plant-pathology/images/Train_768.jpg
#   inflating: plant-pathology/images/Train_769.jpg
#   inflating: plant-pathology/images/Train_77.jpg
#   inflating: plant-pathology/images/Train_770.jpg
#   inflating: plant-pathology/images/Train_771.jpg
#   inflating: plant-pathology/images/Train_772.jpg
#   inflating: plant-pathology/images/Train_773.jpg
#   inflating: plant-pathology/images/Train_774.jpg
#   inflating: plant-pathology/images/Train_775.jpg
#   inflating: plant-pathology/images/Train_776.jpg
#   inflating: plant-pathology/images/Train_777.jpg
#   inflating: plant-pathology/images/Train_778.jpg
#   inflating: plant-pathology/images/Train_779.jpg
#   inflating: plant-pathology/images/Train_78.jpg
#   inflating: plant-pathology/images/Train_780.jpg
#   inflating: plant-pathology/images/Train_781.jpg
#   inflating: plant-pathology/images/Train_782.jpg
#   inflating: plant-pathology/images/Train_783.jpg
#   inflating: plant-pathology/images/Train_784.jpg
#   inflating: plant-pathology/images/Train_785.jpg
#   inflating: plant-pathology/images/Train_786.jpg
#   inflating: plant-pathology/images/Train_787.jpg
#   inflating: plant-pathology/images/Train_788.jpg
#   inflating: plant-pathology/images/Train_789.jpg
#   inflating: plant-pathology/images/Train_79.jpg
#   inflating: plant-pathology/images/Train_790.jpg
#   inflating: plant-pathology/images/Train_791.jpg
#   inflating: plant-pathology/images/Train_792.jpg
#   inflating: plant-pathology/images/Train_793.jpg
#   inflating: plant-pathology/images/Train_794.jpg
#   inflating: plant-pathology/images/Train_795.jpg
#   inflating: plant-pathology/images/Train_796.jpg
#   inflating: plant-pathology/images/Train_797.jpg
#   inflating: plant-pathology/images/Train_798.jpg
#   inflating: plant-pathology/images/Train_799.jpg
#   inflating: plant-pathology/images/Train_8.jpg
#   inflating: plant-pathology/images/Train_80.jpg
#   inflating: plant-pathology/images/Train_800.jpg
#   inflating: plant-pathology/images/Train_801.jpg
#   inflating: plant-pathology/images/Train_802.jpg
#   inflating: plant-pathology/images/Train_803.jpg
#   inflating: plant-pathology/images/Train_804.jpg
#   inflating: plant-pathology/images/Train_805.jpg
#   inflating: plant-pathology/images/Train_806.jpg
#   inflating: plant-pathology/images/Train_807.jpg
#   inflating: plant-pathology/images/Train_808.jpg
#   inflating: plant-pathology/images/Train_809.jpg
#   inflating: plant-pathology/images/Train_81.jpg
#   inflating: plant-pathology/images/Train_810.jpg
#   inflating: plant-pathology/images/Train_811.jpg
#   inflating: plant-pathology/images/Train_812.jpg
#   inflating: plant-pathology/images/Train_813.jpg
#   inflating: plant-pathology/images/Train_814.jpg
#   inflating: plant-pathology/images/Train_815.jpg
#   inflating: plant-pathology/images/Train_816.jpg
#   inflating: plant-pathology/images/Train_817.jpg
#   inflating: plant-pathology/images/Train_818.jpg
#   inflating: plant-pathology/images/Train_819.jpg
#   inflating: plant-pathology/images/Train_82.jpg
#   inflating: plant-pathology/images/Train_820.jpg
#   inflating: plant-pathology/images/Train_821.jpg
#   inflating: plant-pathology/images/Train_822.jpg
#   inflating: plant-pathology/images/Train_823.jpg
#   inflating: plant-pathology/images/Train_824.jpg
#   inflating: plant-pathology/images/Train_825.jpg
#   inflating: plant-pathology/images/Train_826.jpg
#   inflating: plant-pathology/images/Train_827.jpg
#   inflating: plant-pathology/images/Train_828.jpg
#   inflating: plant-pathology/images/Train_829.jpg
#   inflating: plant-pathology/images/Train_83.jpg
#   inflating: plant-pathology/images/Train_830.jpg
#   inflating: plant-pathology/images/Train_831.jpg
#   inflating: plant-pathology/images/Train_832.jpg
#   inflating: plant-pathology/images/Train_833.jpg
#   inflating: plant-pathology/images/Train_834.jpg
#   inflating: plant-pathology/images/Train_835.jpg
#   inflating: plant-pathology/images/Train_836.jpg
#   inflating: plant-pathology/images/Train_837.jpg
#   inflating: plant-pathology/images/Train_838.jpg
#   inflating: plant-pathology/images/Train_839.jpg
#   inflating: plant-pathology/images/Train_84.jpg
#   inflating: plant-pathology/images/Train_840.jpg
#   inflating: plant-pathology/images/Train_841.jpg
#   inflating: plant-pathology/images/Train_842.jpg
#   inflating: plant-pathology/images/Train_843.jpg
#   inflating: plant-pathology/images/Train_844.jpg
#   inflating: plant-pathology/images/Train_845.jpg
#   inflating: plant-pathology/images/Train_846.jpg
#   inflating: plant-pathology/images/Train_847.jpg
#   inflating: plant-pathology/images/Train_848.jpg
#   inflating: plant-pathology/images/Train_849.jpg
#   inflating: plant-pathology/images/Train_85.jpg
#   inflating: plant-pathology/images/Train_850.jpg
#   inflating: plant-pathology/images/Train_851.jpg
#   inflating: plant-pathology/images/Train_852.jpg
#   inflating: plant-pathology/images/Train_853.jpg
#   inflating: plant-pathology/images/Train_854.jpg
#   inflating: plant-pathology/images/Train_855.jpg
#   inflating: plant-pathology/images/Train_856.jpg
#   inflating: plant-pathology/images/Train_857.jpg
#   inflating: plant-pathology/images/Train_858.jpg
#   inflating: plant-pathology/images/Train_859.jpg
#   inflating: plant-pathology/images/Train_86.jpg
#   inflating: plant-pathology/images/Train_860.jpg
#   inflating: plant-pathology/images/Train_861.jpg
#   inflating: plant-pathology/images/Train_862.jpg
#   inflating: plant-pathology/images/Train_863.jpg
#   inflating: plant-pathology/images/Train_864.jpg
#   inflating: plant-pathology/images/Train_865.jpg
#   inflating: plant-pathology/images/Train_866.jpg
#   inflating: plant-pathology/images/Train_867.jpg
#   inflating: plant-pathology/images/Train_868.jpg
#   inflating: plant-pathology/images/Train_869.jpg
#   inflating: plant-pathology/images/Train_87.jpg
#   inflating: plant-pathology/images/Train_870.jpg
#   inflating: plant-pathology/images/Train_871.jpg
#   inflating: plant-pathology/images/Train_872.jpg
#   inflating: plant-pathology/images/Train_873.jpg
#   inflating: plant-pathology/images/Train_874.jpg
#   inflating: plant-pathology/images/Train_875.jpg
#   inflating: plant-pathology/images/Train_876.jpg
#   inflating: plant-pathology/images/Train_877.jpg
#   inflating: plant-pathology/images/Train_878.jpg
#   inflating: plant-pathology/images/Train_879.jpg
#   inflating: plant-pathology/images/Train_88.jpg
#   inflating: plant-pathology/images/Train_880.jpg
#   inflating: plant-pathology/images/Train_881.jpg
#   inflating: plant-pathology/images/Train_882.jpg
#   inflating: plant-pathology/images/Train_883.jpg
#   inflating: plant-pathology/images/Train_884.jpg
#   inflating: plant-pathology/images/Train_885.jpg
#   inflating: plant-pathology/images/Train_886.jpg
#   inflating: plant-pathology/images/Train_887.jpg
#   inflating: plant-pathology/images/Train_888.jpg
#   inflating: plant-pathology/images/Train_889.jpg
#   inflating: plant-pathology/images/Train_89.jpg
#   inflating: plant-pathology/images/Train_890.jpg
#   inflating: plant-pathology/images/Train_891.jpg
#   inflating: plant-pathology/images/Train_892.jpg
#   inflating: plant-pathology/images/Train_893.jpg
#   inflating: plant-pathology/images/Train_894.jpg
#   inflating: plant-pathology/images/Train_895.jpg
#   inflating: plant-pathology/images/Train_896.jpg
#   inflating: plant-pathology/images/Train_897.jpg
#   inflating: plant-pathology/images/Train_898.jpg
#   inflating: plant-pathology/images/Train_899.jpg
#   inflating: plant-pathology/images/Train_9.jpg
#   inflating: plant-pathology/images/Train_90.jpg
#   inflating: plant-pathology/images/Train_900.jpg
#   inflating: plant-pathology/images/Train_901.jpg
#   inflating: plant-pathology/images/Train_902.jpg
#   inflating: plant-pathology/images/Train_903.jpg
#   inflating: plant-pathology/images/Train_904.jpg
#   inflating: plant-pathology/images/Train_905.jpg
#   inflating: plant-pathology/images/Train_906.jpg
#   inflating: plant-pathology/images/Train_907.jpg
#   inflating: plant-pathology/images/Train_908.jpg
#   inflating: plant-pathology/images/Train_909.jpg
#   inflating: plant-pathology/images/Train_91.jpg
#   inflating: plant-pathology/images/Train_910.jpg
#   inflating: plant-pathology/images/Train_911.jpg
#   inflating: plant-pathology/images/Train_912.jpg
#   inflating: plant-pathology/images/Train_913.jpg
#   inflating: plant-pathology/images/Train_914.jpg
#   inflating: plant-pathology/images/Train_915.jpg
#   inflating: plant-pathology/images/Train_916.jpg
#   inflating: plant-pathology/images/Train_917.jpg
#   inflating: plant-pathology/images/Train_918.jpg
#   inflating: plant-pathology/images/Train_919.jpg
#   inflating: plant-pathology/images/Train_92.jpg
#   inflating: plant-pathology/images/Train_920.jpg
#   inflating: plant-pathology/images/Train_921.jpg
#   inflating: plant-pathology/images/Train_922.jpg
#   inflating: plant-pathology/images/Train_923.jpg
#   inflating: plant-pathology/images/Train_924.jpg
#   inflating: plant-pathology/images/Train_925.jpg
#   inflating: plant-pathology/images/Train_926.jpg
#   inflating: plant-pathology/images/Train_927.jpg
#   inflating: plant-pathology/images/Train_928.jpg
#   inflating: plant-pathology/images/Train_929.jpg
#   inflating: plant-pathology/images/Train_93.jpg
#   inflating: plant-pathology/images/Train_930.jpg
#   inflating: plant-pathology/images/Train_931.jpg
#   inflating: plant-pathology/images/Train_932.jpg
#   inflating: plant-pathology/images/Train_933.jpg
#   inflating: plant-pathology/images/Train_934.jpg
#   inflating: plant-pathology/images/Train_935.jpg
#   inflating: plant-pathology/images/Train_936.jpg
#   inflating: plant-pathology/images/Train_937.jpg
#   inflating: plant-pathology/images/Train_938.jpg
#   inflating: plant-pathology/images/Train_939.jpg
#   inflating: plant-pathology/images/Train_94.jpg
#   inflating: plant-pathology/images/Train_940.jpg
#   inflating: plant-pathology/images/Train_941.jpg
#   inflating: plant-pathology/images/Train_942.jpg
#   inflating: plant-pathology/images/Train_943.jpg
#   inflating: plant-pathology/images/Train_944.jpg
#   inflating: plant-pathology/images/Train_945.jpg
#   inflating: plant-pathology/images/Train_946.jpg
#   inflating: plant-pathology/images/Train_947.jpg
#   inflating: plant-pathology/images/Train_948.jpg
#   inflating: plant-pathology/images/Train_949.jpg
#   inflating: plant-pathology/images/Train_95.jpg
#   inflating: plant-pathology/images/Train_950.jpg
#   inflating: plant-pathology/images/Train_951.jpg
#   inflating: plant-pathology/images/Train_952.jpg
#   inflating: plant-pathology/images/Train_953.jpg
#   inflating: plant-pathology/images/Train_954.jpg
#   inflating: plant-pathology/images/Train_955.jpg
#   inflating: plant-pathology/images/Train_956.jpg
#   inflating: plant-pathology/images/Train_957.jpg
#   inflating: plant-pathology/images/Train_958.jpg
#   inflating: plant-pathology/images/Train_959.jpg
#   inflating: plant-pathology/images/Train_96.jpg
#   inflating: plant-pathology/images/Train_960.jpg
#   inflating: plant-pathology/images/Train_961.jpg
#   inflating: plant-pathology/images/Train_962.jpg
#   inflating: plant-pathology/images/Train_963.jpg
#   inflating: plant-pathology/images/Train_964.jpg
#   inflating: plant-pathology/images/Train_965.jpg
#   inflating: plant-pathology/images/Train_966.jpg
#   inflating: plant-pathology/images/Train_967.jpg
#   inflating: plant-pathology/images/Train_968.jpg
#   inflating: plant-pathology/images/Train_969.jpg
#   inflating: plant-pathology/images/Train_97.jpg
#   inflating: plant-pathology/images/Train_970.jpg
#   inflating: plant-pathology/images/Train_971.jpg
#   inflating: plant-pathology/images/Train_972.jpg
#   inflating: plant-pathology/images/Train_973.jpg
#   inflating: plant-pathology/images/Train_974.jpg
#   inflating: plant-pathology/images/Train_975.jpg
#   inflating: plant-pathology/images/Train_976.jpg
#   inflating: plant-pathology/images/Train_977.jpg
#   inflating: plant-pathology/images/Train_978.jpg
#   inflating: plant-pathology/images/Train_979.jpg
#   inflating: plant-pathology/images/Train_98.jpg
#   inflating: plant-pathology/images/Train_980.jpg
#   inflating: plant-pathology/images/Train_981.jpg
#   inflating: plant-pathology/images/Train_982.jpg
#   inflating: plant-pathology/images/Train_983.jpg
#   inflating: plant-pathology/images/Train_984.jpg
#   inflating: plant-pathology/images/Train_985.jpg
#   inflating: plant-pathology/images/Train_986.jpg
#   inflating: plant-pathology/images/Train_987.jpg
#   inflating: plant-pathology/images/Train_988.jpg
#   inflating: plant-pathology/images/Train_989.jpg
#   inflating: plant-pathology/images/Train_99.jpg
#   inflating: plant-pathology/images/Train_990.jpg
#   inflating: plant-pathology/images/Train_991.jpg
#   inflating: plant-pathology/images/Train_992.jpg
#   inflating: plant-pathology/images/Train_993.jpg
#   inflating: plant-pathology/images/Train_994.jpg
#   inflating: plant-pathology/images/Train_995.jpg
#   inflating: plant-pathology/images/Train_996.jpg
#   inflating: plant-pathology/images/Train_997.jpg
#   inflating: plant-pathology/images/Train_998.jpg
#   inflating: plant-pathology/images/Train_999.jpg
#   inflating: plant-pathology/sample_submission.csv
#   inflating: plant-pathology/test.csv
#   inflating: plant-pathology/train.csv

# %% [markdown]
# 파라미터 설정

# %% [markdown]
# ## train.csv 전처리

# %% [markdown]
# - healthy = 0
# - multiple_diseases = 1
# - rust = 2
# - scab = 3

# %%
df_train = pd.read_csv('./plant-pathology/train.csv')
df_train
# Out:
#         image_id  healthy  multiple_diseases  rust  scab
# 0        Train_0        0                  0     0     1
# 1        Train_1        0                  1     0     0
# 2        Train_2        1                  0     0     0
# 3        Train_3        0                  0     1     0
# 4        Train_4        1                  0     0     0
# ...          ...      ...                ...   ...   ...
# 1816  Train_1816        0                  0     0     1
# 1817  Train_1817        1                  0     0     0
# 1818  Train_1818        1                  0     0     0
# 1819  Train_1819        0                  0     1     0
# 1820  Train_1820        0                  0     0     1
#
# [1821 rows x 5 columns]

# %%
df_train.loc[df_train['healthy'] == 1, 'label'] = 0
df_train.loc[df_train['multiple_diseases'] == 1, 'label'] = 1
df_train.loc[df_train['rust'] == 1, 'label'] = 2
df_train.loc[df_train['scab'] == 1, 'label'] = 3

# 정수 형태로 변환
df_train['label'] = df_train['label'].apply(lambda x : int(x)) 

# 필요없는 columns 제거
df_train.drop(['healthy', 'multiple_diseases', 'rust', 'scab'], inplace=True, axis=1)

# %%
df_train.head()
# Out:
#   image_id  label
# 0  Train_0      3
# 1  Train_1      1
# 2  Train_2      0
# 3  Train_3      2
# 4  Train_4      0

# %% [markdown]
# # img path 가져오기

# %%
from glob import glob

def get_train_data(data_dir):
    img_path_list = []
    label_list = []
    
    img_path_list.extend(glob(os.path.join(data_dir, 'Train_*.jpg')))
    img_path_list.sort(key=lambda x:int(x.split('/')[-1].split('_')[1].split('.')[0]))
        

    label_list.extend(df_train['label'])
                
    return img_path_list, label_list

def get_test_data(data_dir):
    img_path_list = []
    
    img_path_list.extend(glob(os.path.join(data_dir, 'Test_*.jpg')))
    img_path_list.sort(key=lambda x:int(x.split('/')[-1].split('_')[1].split('.')[0]))

    
    return img_path_list

# %%
all_img_path, all_label = get_train_data('./plant-pathology/images')
test_img_path = get_test_data('./plant-pathology/images')

# %%
# img path에 5번째만 보여주기
for p, l in zip(all_img_path[:5], all_label[:5]):
    print(p, l)
# Out:
# ./plant-pathology/images/Train_0.jpg 3
# ./plant-pathology/images/Train_1.jpg 1
# ./plant-pathology/images/Train_2.jpg 0
# ./plant-pathology/images/Train_3.jpg 2
# ./plant-pathology/images/Train_4.jpg 0

# %%
print(len(all_img_path), len(all_label), len(test_img_path))
print(all_label[:5])
# Out:
# 1821 1821 1821
# [3, 1, 0, 2, 0]

# %% [markdown]
# ## 이미지 경로 -> 이미지로 변환

# %%
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from PIL import Image

from torch.utils.data import DataLoader
from torch.utils.data import DataLoader, Dataset

class CustomDataset(Dataset):
    def __init__(self, img_path_list, label_list, train_mode=True, transforms=None):
        self.transforms = transforms
        self.train_mode = train_mode
        self.img_path_list = img_path_list
        self.label_list = label_list

    def __getitem__(self, index):
        img_path = self.img_path_list[index]
        # Get image data
        image = Image.open(img_path)
        if self.transforms is not None:
            image = self.transforms(image)

        if self.train_mode:
            label = self.label_list[index]
            return image, label
        else:
            return image
    
    def __len__(self):
        return len(self.img_path_list)

# %% [markdown]
# ## 훈련 데이터셋 분리 (0.75):(0.25)

# %%
train_len = int(len(all_img_path)*0.75) # train 0.75
valid_len = int(len(all_img_path)*0.25)  # valid 0.25

# 데이터 분리
train_img_path = all_img_path[:train_len] 
train_label = all_label[:train_len]

# 정답 분리
valid_img_path = all_img_path[train_len:]
valid_label = all_label[train_len:]

# %%
print('train set 길이 : ', train_len)
print('vaildation set 길이 : ', valid_len)
# Out:
# train set 길이 :  1365
# vaildation set 길이 :  455

# %% [markdown]
# - train 1365
# - valid 455

# %% [markdown]
# # RGB 값의 mean과 std를 구한다.

# %% [markdown]
# - Tensor로만 변환시

# %%
train_ds = CustomDataset(train_img_path, train_label, train_mode=True, transforms=transforms.ToTensor())
val_ds = CustomDataset(valid_img_path, valid_label, train_mode=True, transforms=transforms.ToTensor())

# %%
train_ds_ = DataLoader(train_ds, batch_size = CFG['BATCH_SIZE'], shuffle=True, num_workers=0) 
val_ds_ = DataLoader(val_ds, batch_size = CFG['BATCH_SIZE'], shuffle=True, num_workers=0)

# %%
train_features, train_labels = train_ds[0] 

img = train_features
label = train_labels
plt.imshow(img.permute(1,2,0))
plt.show()
print(f"Label: {label}")
# Out:
# Label: 3

# %%
def imshow(img):         
    #img = img * 0.5 + 0.5 #unnormalize (normalize : (data - 0.5)/0.5))
    plt.figure(figsize=(20, 200))
    plt.imshow(img.permute(1, 2, 0))

dataiter = iter(train_ds_)
dataiter.next()
images, labels = dataiter.next() # 32개의 image, 32개의 label

imshow(torchvision.utils.make_grid(images, nrows=8))
print(labels)
# Out:
# tensor([2, 3, 0, 2])

# %%
print(images[0].shape) # C x H x W
# Out:
# torch.Size([3, 1365, 2048])

# %% [markdown]
# ## 이미지 변환 준비
# - Normalize를 위해
# - 각 RGB의 mean과 std 를 구한다.

# %%
train_ds = CustomDataset(train_img_path, train_label, train_mode=True, transforms=transforms.ToTensor()) 

val_ds = CustomDataset(valid_img_path, valid_label, train_mode=True, transforms=transforms.ToTensor())

# %%
# train_meanRGB = [np.mean(x.numpy(), axis=(1,2)) for x, _ in train_ds]
# train_stdRGB = [np.std(x.numpy(), axis=(1,2)) for x, _ in train_ds]

# meanR = round(np.mean([m[0] for m in train_meanRGB]),4)
# meanG = round(np.mean([m[1] for m in train_meanRGB]),4)
# meanB = round(np.mean([m[2] for m in train_meanRGB]),4)
# stdR = round(np.std([s[0] for s in train_stdRGB]),4)
# stdG = round(np.std([s[1] for s in train_stdRGB]),4)
# stdB = round(np.std([s[2] for s in train_stdRGB]),4)
meanR = 0.40619999170303345
meanG = 0.5149000287055969
meanB = 0.31290000677108765
stdR = 0.043299999088048935
stdG = 0.042500000447034836
stdB = 0.03759999945759773

# %%
print(f'meanR : {meanR}, meanG : {meanG}, meanB : {meanB}')
print(f'stdR : {stdR}, stdG : {stdG}, train_stdB : {stdB}')
# Out:
# meanR : 0.40619999170303345, meanG : 0.5149000287055969, meanB : 0.31290000677108765
# stdR : 0.043299999088048935, stdG : 0.042500000447034836, train_stdB : 0.03759999945759773

# %% [markdown]
# # 이미지 변경
# - 사이즈 800, 1200
# - 0.5 확률 좌우 대칭
# - 0.5 확률 상하 대칭
# - 0~180도 회전
# - 확대
# - 텐서로 변환

# %%
# import albumentations as A
# from albumentations.pytorch import ToTensor
# import cv2

# train_transform = A.Compose([
#                             ToTensor(),
#                             A.Resize(CFG['IMG_SIZE_W'], CFG['IMG_SIZE_H']),
#                             A.HorizontalFlip(p=0.5),
#                             A.VerticalFlip(p=0.5),
#                             A.Rotate(limit=(0, 180), p=0.5, border_mode=cv2.BORDER_CONSTANT),
#                             A.CenterCrop(CFG['IMG_SIZE_W'], CFG['IMG_SIZE_H']),
#                             A.Normalize(mean=(meanR, meanG, meanB), std=(stdR, stdG, stdB), max_pixel_value=255.0, always_apply=False, p=1.0)
#                             ])

# vali_transform = A.Compose([
#                             ToTensor(),
#                             A.Resize(CFG['IMG_SIZE_W'], CFG['IMG_SIZE_H']),
#                             A.Normalize(mean=(meanR, meanG, meanB), std=(stdR, stdG, stdB), max_pixel_value=255.0, always_apply=False, p=1.0)
#                             ])

# test_transform = A.Compose([A.Resize(CFG['IMG_SIZE_W'], CFG['IMG_SIZE_H']),
#                             ToTensor(),
#                             A.Normalize(mean=(meanR, meanG, meanB), std=(stdR, stdG, stdB), max_pixel_value=255.0, always_apply=False, p=1.0)
#                             ])

# %%
from torchvision.transforms.transforms import RandomRotation
train_transform = transforms.Compose([
                    transforms.ToTensor(), 
                    transforms.Resize([CFG['IMG_SIZE_W'], CFG['IMG_SIZE_H']]), 
                    transforms.RandomHorizontalFlip(p=0.5),
                    transforms.RandomVerticalFlip(p=0.5),
                    transforms.RandomRotation(degrees=(0, 180)),
                    transforms.CenterCrop((CFG['IMG_SIZE_W'], CFG['IMG_SIZE_H'])),
                    transforms.Normalize(mean=(meanR, meanG, meanB), std=(stdR, stdG, stdB))
                    ])

vali_transform = transforms.Compose([
                    transforms.ToTensor(), 
                    transforms.Resize([CFG['IMG_SIZE_W'], CFG['IMG_SIZE_H']]),
                    transforms.Normalize(mean=(meanR, meanG, meanB), std=(stdR, stdG, stdB))
                    ])

test_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Resize([CFG['IMG_SIZE_W'], CFG['IMG_SIZE_H']]),
                                     transforms.Normalize(mean=(meanR, meanG, meanB), std=(stdR, stdG, stdB))
                                     ])

# %%
train_ds = CustomDataset(train_img_path, train_label, train_mode=True, transforms=train_transform) 

val_ds = CustomDataset(valid_img_path, valid_label, train_mode=True, transforms=vali_transform) 

test_ds = CustomDataset(test_img_path, valid_label, train_mode=False, transforms=test_transform)

# %%
train_loader = DataLoader(train_ds, batch_size = CFG['BATCH_SIZE'], shuffle=True, num_workers=0) 
vali_loader = DataLoader(val_ds, batch_size = CFG['BATCH_SIZE'], shuffle=False, num_workers=0)
test_loader = DataLoader(test_ds, batch_size = CFG['BATCH_SIZE'], shuffle=False, num_workers=0)

# %%
train_features, train_labels = train_ds[0] 

img = train_features
label = train_labels
plt.imshow(img.permute(1,2,0))
plt.show()
print(f"Label: {label}")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label: 3

# %%
print(len(train_loader), len(vali_loader))
print(type(train_loader), type(vali_loader))
# Out:
# 342 114
# <class 'torch.utils.data.dataloader.DataLoader'> <class 'torch.utils.data.dataloader.DataLoader'>

# %%
def imshow(img):         
    plt.figure(figsize=(20, 200))
    plt.imshow(img.permute(1, 2, 0))

dataiter = iter(train_loader)
images, labels = dataiter.next() 

imshow(torchvision.utils.make_grid(images, nrows=8))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # 모델 생성

# %% [markdown]
# ![resnet.png](data:image/png;base64,...)

# %%
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

class BasicBlock(nn.Module):
    expansion = 1
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()

        # BatchNorm에 bias가 포함되어 있으므로, conv2d는 bias=False로 설정합니다.
        self.residual_function = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(),
            nn.Conv2d(out_channels, out_channels * BasicBlock.expansion, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(out_channels * BasicBlock.expansion),
        )

        # identity mapping, input과 output의 feature map size, filter 수가 동일한 경우 사용.
        self.shortcut = nn.Sequential()

        self.relu = nn.LeakyReLU()

        # projection mapping using 1x1conv
        if stride != 1 or in_channels != BasicBlock.expansion * out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels * BasicBlock.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels * BasicBlock.expansion)
            )

    def forward(self, x):
        x = self.residual_function(x) + self.shortcut(x)
        x = self.relu(x)
        return x


class BottleNeck(nn.Module):
    expansion = 4
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()

        self.residual_function = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(),
            nn.Conv2d(out_channels, out_channels * BottleNeck.expansion, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels * BottleNeck.expansion),
        )

        self.shortcut = nn.Sequential()

        self.relu = nn.LeakyReLU()

        if stride != 1 or in_channels != out_channels * BottleNeck.expansion:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels*BottleNeck.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels*BottleNeck.expansion)
            )
            
    def forward(self, x):
        x = self.residual_function(x) + self.shortcut(x)
        x = self.relu(x)
        return x
    
class ResNet(nn.Module):
    def __init__(self, block, num_block, num_classes=4, init_weights=True):
        super().__init__()

        self.in_channels=64

        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )

        self.conv2_x = self._make_layer(block, 64, num_block[0], 1)
        self.conv3_x = self._make_layer(block, 128, num_block[1], 2)
        self.conv4_x = self._make_layer(block, 256, num_block[2], 2)
        self.conv5_x = self._make_layer(block, 512, num_block[3], 2)

        self.avg_pool = nn.AdaptiveAvgPool2d((1,1))
        self.fc = nn.Linear(512 * block.expansion, num_classes)

        # weights inittialization
        if init_weights:
            self._initialize_weights()

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels * block.expansion

        return nn.Sequential(*layers)

    def forward(self,x):
        output = self.conv1(x)
        output = self.conv2_x(output)
        x = self.conv3_x(output)
        x = self.conv4_x(x)
        x = self.conv5_x(x)
        x = self.avg_pool(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

    # define weight initialization function
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

def resnet18():
    return ResNet(BasicBlock, [2,2,2,2])

def resnet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])

def resnet50():
    return ResNet(BottleNeck, [3,4,6,3])

def resnet101():
    return ResNet(BottleNeck, [3, 4, 23, 3])

def resnet152():
    return ResNet(BottleNeck, [3, 8, 36, 3])

# %%
# 추가
state_dict = torch.load(dir +"last_checkpoint_resnet.pth") 
model = resnet101()
model.to(device)
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
from torchsummary import summary
summary(model, (3, CFG['IMG_SIZE_W'], CFG['IMG_SIZE_H']))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 400, 600]           9,408
#        BatchNorm2d-2         [-1, 64, 400, 600]             128
#          LeakyReLU-3         [-1, 64, 400, 600]               0
#          MaxPool2d-4         [-1, 64, 200, 300]               0
#             Conv2d-5         [-1, 64, 200, 300]           4,096
#        BatchNorm2d-6         [-1, 64, 200, 300]             128
#          LeakyReLU-7         [-1, 64, 200, 300]               0
#             Conv2d-8         [-1, 64, 200, 300]          36,864
#        BatchNorm2d-9         [-1, 64, 200, 300]             128
#         LeakyReLU-10         [-1, 64, 200, 300]               0
#            Conv2d-11        [-1, 256, 200, 300]          16,384
#       BatchNorm2d-12        [-1, 256, 200, 300]             512
#            Conv2d-13        [-1, 256, 200, 300]          16,384
#       BatchNorm2d-14        [-1, 256, 200, 300]             512
#         LeakyReLU-15        [-1, 256, 200, 300]               0
#        BottleNeck-16        [-1, 256, 200, 300]               0
#            Conv2d-17         [-1, 64, 200, 300]          16,384
#       BatchNorm2d-18         [-1, 64, 200, 300]             128
#         LeakyReLU-19         [-1, 64, 200, 300]               0
#            Conv2d-20         [-1, 64, 200, 300]          36,864
#       BatchNorm2d-21         [-1, 64, 200, 300]             128
#         LeakyReLU-22         [-1, 64, 200, 300]               0
#            Conv2d-23        [-1, 256, 200, 300]          16,384
#       BatchNorm2d-24        [-1, 256, 200, 300]             512
#         LeakyReLU-25        [-1, 256, 200, 300]               0
#        BottleNeck-26        [-1, 256, 200, 300]               0
#            Conv2d-27         [-1, 64, 200, 300]          16,384
#       BatchNorm2d-28         [-1, 64, 200, 300]             128
#         LeakyReLU-29         [-1, 64, 200, 300]               0
#            Conv2d-30         [-1, 64, 200, 300]          36,864
#       BatchNorm2d-31         [-1, 64, 200, 300]             128
#         LeakyReLU-32         [-1, 64, 200, 300]               0
#            Conv2d-33        [-1, 256, 200, 300]          16,384
#       BatchNorm2d-34        [-1, 256, 200, 300]             512
#         LeakyReLU-35        [-1, 256, 200, 300]               0
#        BottleNeck-36        [-1, 256, 200, 300]               0
#            Conv2d-37        [-1, 128, 200, 300]          32,768
#       BatchNorm2d-38        [-1, 128, 200, 300]             256
#         LeakyReLU-39        [-1, 128, 200, 300]               0
#            Conv2d-40        [-1, 128, 100, 150]         147,456
#       BatchNorm2d-41        [-1, 128, 100, 150]             256
#         LeakyReLU-42        [-1, 128, 100, 150]               0
#            Conv2d-43        [-1, 512, 100, 150]          65,536
#       BatchNorm2d-44        [-1, 512, 100, 150]           1,024
#            Conv2d-45        [-1, 512, 100, 150]         131,072
#       BatchNorm2d-46        [-1, 512, 100, 150]           1,024
#         LeakyReLU-47        [-1, 512, 100, 150]               0
#        BottleNeck-48        [-1, 512, 100, 150]               0
#            Conv2d-49        [-1, 128, 100, 150]          65,536
#       BatchNorm2d-50        [-1, 128, 100, 150]             256
#         LeakyReLU-51        [-1, 128, 100, 150]               0
#            Conv2d-52        [-1, 128, 100, 150]         147,456
#       BatchNorm2d-53        [-1, 128, 100, 150]             256
#         LeakyReLU-54        [-1, 128, 100, 150]               0
#            Conv2d-55        [-1, 512, 100, 150]          65,536
#       BatchNorm2d-56        [-1, 512, 100, 150]           1,024
#         LeakyReLU-57        [-1, 512, 100, 150]               0
#        BottleNeck-58        [-1, 512, 100, 150]               0
#            Conv2d-59        [-1, 128, 100, 150]          65,536
#       BatchNorm2d-60        [-1, 128, 100, 150]             256
#         LeakyReLU-61        [-1, 128, 100, 150]               0
#            Conv2d-62        [-1, 128, 100, 150]         147,456
#       BatchNorm2d-63        [-1, 128, 100, 150]             256
#         LeakyReLU-64        [-1, 128, 100, 150]               0
#            Conv2d-65        [-1, 512, 100, 150]          65,536
#       BatchNorm2d-66        [-1, 512, 100, 150]           1,024
#         LeakyReLU-67        [-1, 512, 100, 150]               0
#        BottleNeck-68        [-1, 512, 100, 150]               0
#            Conv2d-69        [-1, 128, 100, 150]          65,536
#       BatchNorm2d-70        [-1, 128, 100, 150]             256
#         LeakyReLU-71        [-1, 128, 100, 150]               0
#            Conv2d-72        [-1, 128, 100, 150]         147,456
#       BatchNorm2d-73        [-1, 128, 100, 150]             256
#         LeakyReLU-74        [-1, 128, 100, 150]               0
#            Conv2d-75        [-1, 512, 100, 150]          65,536
#       BatchNorm2d-76        [-1, 512, 100, 150]           1,024
#         LeakyReLU-77        [-1, 512, 100, 150]               0
#        BottleNeck-78        [-1, 512, 100, 150]               0
#            Conv2d-79        [-1, 256, 100, 150]         131,072
#       BatchNorm2d-80        [-1, 256, 100, 150]             512
#         LeakyReLU-81        [-1, 256, 100, 150]               0
#            Conv2d-82          [-1, 256, 50, 75]         589,824
#       BatchNorm2d-83          [-1, 256, 50, 75]             512
#         LeakyReLU-84          [-1, 256, 50, 75]               0
#            Conv2d-85         [-1, 1024, 50, 75]         262,144
#       BatchNorm2d-86         [-1, 1024, 50, 75]           2,048
#            Conv2d-87         [-1, 1024, 50, 75]         524,288
#       BatchNorm2d-88         [-1, 1024, 50, 75]           2,048
#         LeakyReLU-89         [-1, 1024, 50, 75]               0
#        BottleNeck-90         [-1, 1024, 50, 75]               0
#            Conv2d-91          [-1, 256, 50, 75]         262,144
#       BatchNorm2d-92          [-1, 256, 50, 75]             512
#         LeakyReLU-93          [-1, 256, 50, 75]               0
#            Conv2d-94          [-1, 256, 50, 75]         589,824
#       BatchNorm2d-95          [-1, 256, 50, 75]             512
#         LeakyReLU-96          [-1, 256, 50, 75]               0
#            Conv2d-97         [-1, 1024, 50, 75]         262,144
#       BatchNorm2d-98         [-1, 1024, 50, 75]           2,048
#         LeakyReLU-99         [-1, 1024, 50, 75]               0
#       BottleNeck-100         [-1, 1024, 50, 75]               0
#           Conv2d-101          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-102          [-1, 256, 50, 75]             512
#        LeakyReLU-103          [-1, 256, 50, 75]               0
#           Conv2d-104          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-105          [-1, 256, 50, 75]             512
#        LeakyReLU-106          [-1, 256, 50, 75]               0
#           Conv2d-107         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-108         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-109         [-1, 1024, 50, 75]               0
#       BottleNeck-110         [-1, 1024, 50, 75]               0
#           Conv2d-111          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-112          [-1, 256, 50, 75]             512
#        LeakyReLU-113          [-1, 256, 50, 75]               0
#           Conv2d-114          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-115          [-1, 256, 50, 75]             512
#        LeakyReLU-116          [-1, 256, 50, 75]               0
#           Conv2d-117         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-118         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-119         [-1, 1024, 50, 75]               0
#       BottleNeck-120         [-1, 1024, 50, 75]               0
#           Conv2d-121          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-122          [-1, 256, 50, 75]             512
#        LeakyReLU-123          [-1, 256, 50, 75]               0
#           Conv2d-124          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-125          [-1, 256, 50, 75]             512
#        LeakyReLU-126          [-1, 256, 50, 75]               0
#           Conv2d-127         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-128         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-129         [-1, 1024, 50, 75]               0
#       BottleNeck-130         [-1, 1024, 50, 75]               0
#           Conv2d-131          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-132          [-1, 256, 50, 75]             512
#        LeakyReLU-133          [-1, 256, 50, 75]               0
#           Conv2d-134          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-135          [-1, 256, 50, 75]             512
#        LeakyReLU-136          [-1, 256, 50, 75]               0
#           Conv2d-137         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-138         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-139         [-1, 1024, 50, 75]               0
#       BottleNeck-140         [-1, 1024, 50, 75]               0
#           Conv2d-141          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-142          [-1, 256, 50, 75]             512
#        LeakyReLU-143          [-1, 256, 50, 75]               0
#           Conv2d-144          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-145          [-1, 256, 50, 75]             512
#        LeakyReLU-146          [-1, 256, 50, 75]               0
#           Conv2d-147         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-148         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-149         [-1, 1024, 50, 75]               0
#       BottleNeck-150         [-1, 1024, 50, 75]               0
#           Conv2d-151          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-152          [-1, 256, 50, 75]             512
#        LeakyReLU-153          [-1, 256, 50, 75]               0
#           Conv2d-154          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-155          [-1, 256, 50, 75]             512
#        LeakyReLU-156          [-1, 256, 50, 75]               0
#           Conv2d-157         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-158         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-159         [-1, 1024, 50, 75]               0
#       BottleNeck-160         [-1, 1024, 50, 75]               0
#           Conv2d-161          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-162          [-1, 256, 50, 75]             512
#        LeakyReLU-163          [-1, 256, 50, 75]               0
#           Conv2d-164          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-165          [-1, 256, 50, 75]             512
#        LeakyReLU-166          [-1, 256, 50, 75]               0
#           Conv2d-167         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-168         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-169         [-1, 1024, 50, 75]               0
#       BottleNeck-170         [-1, 1024, 50, 75]               0
#           Conv2d-171          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-172          [-1, 256, 50, 75]             512
#        LeakyReLU-173          [-1, 256, 50, 75]               0
#           Conv2d-174          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-175          [-1, 256, 50, 75]             512
#        LeakyReLU-176          [-1, 256, 50, 75]               0
#           Conv2d-177         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-178         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-179         [-1, 1024, 50, 75]               0
#       BottleNeck-180         [-1, 1024, 50, 75]               0
#           Conv2d-181          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-182          [-1, 256, 50, 75]             512
#        LeakyReLU-183          [-1, 256, 50, 75]               0
#           Conv2d-184          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-185          [-1, 256, 50, 75]             512
#        LeakyReLU-186          [-1, 256, 50, 75]               0
#           Conv2d-187         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-188         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-189         [-1, 1024, 50, 75]               0
#       BottleNeck-190         [-1, 1024, 50, 75]               0
#           Conv2d-191          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-192          [-1, 256, 50, 75]             512
#        LeakyReLU-193          [-1, 256, 50, 75]               0
#           Conv2d-194          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-195          [-1, 256, 50, 75]             512
#        LeakyReLU-196          [-1, 256, 50, 75]               0
#           Conv2d-197         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-198         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-199         [-1, 1024, 50, 75]               0
#       BottleNeck-200         [-1, 1024, 50, 75]               0
#           Conv2d-201          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-202          [-1, 256, 50, 75]             512
#        LeakyReLU-203          [-1, 256, 50, 75]               0
#           Conv2d-204          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-205          [-1, 256, 50, 75]             512
#        LeakyReLU-206          [-1, 256, 50, 75]               0
#           Conv2d-207         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-208         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-209         [-1, 1024, 50, 75]               0
#       BottleNeck-210         [-1, 1024, 50, 75]               0
#           Conv2d-211          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-212          [-1, 256, 50, 75]             512
#        LeakyReLU-213          [-1, 256, 50, 75]               0
#           Conv2d-214          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-215          [-1, 256, 50, 75]             512
#        LeakyReLU-216          [-1, 256, 50, 75]               0
#           Conv2d-217         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-218         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-219         [-1, 1024, 50, 75]               0
#       BottleNeck-220         [-1, 1024, 50, 75]               0
#           Conv2d-221          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-222          [-1, 256, 50, 75]             512
#        LeakyReLU-223          [-1, 256, 50, 75]               0
#           Conv2d-224          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-225          [-1, 256, 50, 75]             512
#        LeakyReLU-226          [-1, 256, 50, 75]               0
#           Conv2d-227         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-228         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-229         [-1, 1024, 50, 75]               0
#       BottleNeck-230         [-1, 1024, 50, 75]               0
#           Conv2d-231          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-232          [-1, 256, 50, 75]             512
#        LeakyReLU-233          [-1, 256, 50, 75]               0
#           Conv2d-234          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-235          [-1, 256, 50, 75]             512
#        LeakyReLU-236          [-1, 256, 50, 75]               0
#           Conv2d-237         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-238         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-239         [-1, 1024, 50, 75]               0
#       BottleNeck-240         [-1, 1024, 50, 75]               0
#           Conv2d-241          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-242          [-1, 256, 50, 75]             512
#        LeakyReLU-243          [-1, 256, 50, 75]               0
#           Conv2d-244          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-245          [-1, 256, 50, 75]             512
#        LeakyReLU-246          [-1, 256, 50, 75]               0
#           Conv2d-247         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-248         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-249         [-1, 1024, 50, 75]               0
#       BottleNeck-250         [-1, 1024, 50, 75]               0
#           Conv2d-251          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-252          [-1, 256, 50, 75]             512
#        LeakyReLU-253          [-1, 256, 50, 75]               0
#           Conv2d-254          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-255          [-1, 256, 50, 75]             512
#        LeakyReLU-256          [-1, 256, 50, 75]               0
#           Conv2d-257         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-258         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-259         [-1, 1024, 50, 75]               0
#       BottleNeck-260         [-1, 1024, 50, 75]               0
#           Conv2d-261          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-262          [-1, 256, 50, 75]             512
#        LeakyReLU-263          [-1, 256, 50, 75]               0
#           Conv2d-264          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-265          [-1, 256, 50, 75]             512
#        LeakyReLU-266          [-1, 256, 50, 75]               0
#           Conv2d-267         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-268         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-269         [-1, 1024, 50, 75]               0
#       BottleNeck-270         [-1, 1024, 50, 75]               0
#           Conv2d-271          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-272          [-1, 256, 50, 75]             512
#        LeakyReLU-273          [-1, 256, 50, 75]               0
#           Conv2d-274          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-275          [-1, 256, 50, 75]             512
#        LeakyReLU-276          [-1, 256, 50, 75]               0
#           Conv2d-277         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-278         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-279         [-1, 1024, 50, 75]               0
#       BottleNeck-280         [-1, 1024, 50, 75]               0
#           Conv2d-281          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-282          [-1, 256, 50, 75]             512
#        LeakyReLU-283          [-1, 256, 50, 75]               0
#           Conv2d-284          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-285          [-1, 256, 50, 75]             512
#        LeakyReLU-286          [-1, 256, 50, 75]               0
#           Conv2d-287         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-288         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-289         [-1, 1024, 50, 75]               0
#       BottleNeck-290         [-1, 1024, 50, 75]               0
#           Conv2d-291          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-292          [-1, 256, 50, 75]             512
#        LeakyReLU-293          [-1, 256, 50, 75]               0
#           Conv2d-294          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-295          [-1, 256, 50, 75]             512
#        LeakyReLU-296          [-1, 256, 50, 75]               0
#           Conv2d-297         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-298         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-299         [-1, 1024, 50, 75]               0
#       BottleNeck-300         [-1, 1024, 50, 75]               0
#           Conv2d-301          [-1, 256, 50, 75]         262,144
#      BatchNorm2d-302          [-1, 256, 50, 75]             512
#        LeakyReLU-303          [-1, 256, 50, 75]               0
#           Conv2d-304          [-1, 256, 50, 75]         589,824
#      BatchNorm2d-305          [-1, 256, 50, 75]             512
#        LeakyReLU-306          [-1, 256, 50, 75]               0
#           Conv2d-307         [-1, 1024, 50, 75]         262,144
#      BatchNorm2d-308         [-1, 1024, 50, 75]           2,048
#        LeakyReLU-309         [-1, 1024, 50, 75]               0
#       BottleNeck-310         [-1, 1024, 50, 75]               0
#           Conv2d-311          [-1, 512, 50, 75]         524,288
#      BatchNorm2d-312          [-1, 512, 50, 75]           1,024
#        LeakyReLU-313          [-1, 512, 50, 75]               0
#           Conv2d-314          [-1, 512, 25, 38]       2,359,296
#      BatchNorm2d-315          [-1, 512, 25, 38]           1,024
#        LeakyReLU-316          [-1, 512, 25, 38]               0
#           Conv2d-317         [-1, 2048, 25, 38]       1,048,576
#      BatchNorm2d-318         [-1, 2048, 25, 38]           4,096
#           Conv2d-319         [-1, 2048, 25, 38]       2,097,152
#      BatchNorm2d-320         [-1, 2048, 25, 38]           4,096
#        LeakyReLU-321         [-1, 2048, 25, 38]               0
#       BottleNeck-322         [-1, 2048, 25, 38]               0
#           Conv2d-323          [-1, 512, 25, 38]       1,048,576
#      BatchNorm2d-324          [-1, 512, 25, 38]           1,024
#        LeakyReLU-325          [-1, 512, 25, 38]               0
#           Conv2d-326          [-1, 512, 25, 38]       2,359,296
#      BatchNorm2d-327          [-1, 512, 25, 38]           1,024
#        LeakyReLU-328          [-1, 512, 25, 38]               0
#           Conv2d-329         [-1, 2048, 25, 38]       1,048,576
#      BatchNorm2d-330         [-1, 2048, 25, 38]           4,096
#        LeakyReLU-331         [-1, 2048, 25, 38]               0
#       BottleNeck-332         [-1, 2048, 25, 38]               0
#           Conv2d-333          [-1, 512, 25, 38]       1,048,576
#      BatchNorm2d-334          [-1, 512, 25, 38]           1,024
#        LeakyReLU-335          [-1, 512, 25, 38]               0
#           Conv2d-336          [-1, 512, 25, 38]       2,359,296
#      BatchNorm2d-337          [-1, 512, 25, 38]           1,024
#        LeakyReLU-338          [-1, 512, 25, 38]               0
#           Conv2d-339         [-1, 2048, 25, 38]       1,048,576
#      BatchNorm2d-340         [-1, 2048, 25, 38]           4,096
#        LeakyReLU-341         [-1, 2048, 25, 38]               0
#       BottleNeck-342         [-1, 2048, 25, 38]               0
# AdaptiveAvgPool2d-343           [-1, 2048, 1, 1]               0
#           Linear-344                    [-1, 4]           8,196
# ================================================================
# Total params: 42,508,356
# Trainable params: 42,508,356
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 10.99
# Forward/backward pass size (MB): 8224.92
# Params size (MB): 162.16
# Estimated Total Size (MB): 8398.06
# ----------------------------------------------------------------

# %% [markdown]
# # 모델 훈련

# %%
from torch.utils.tensorboard import SummaryWriter
from sklearn.metrics import roc_auc_score
writer = SummaryWriter()

def validation(model, testloader, criterion):
    test_accuracy = 0
    test_loss = 0
    true_onehot_list = []
    pred_list = []
    with torch.no_grad(): # 예측에는 gradient가 필요 없음
        for images, labels in testloader: # 1 iteration마다 배치 단위로 image와 label을 가져옴
            images, labels = images.to(device), labels.to(device) # data를 GPU로 보내기
            # Not Flatten!!!
            #images.resize_(images.shape[0], 784) # batch size x 784
            
            logits = model.forward(images) # 입력 : batch_size, 28, 28
            
            loss = criterion(logits, labels)
            test_loss += loss.item()

            probs = F.softmax(logits, dim=1)
            
            true_onehot = torch.eye(4)[labels].cpu().numpy()
            preds_ = torch.softmax(logits.cpu(), dim=1).numpy()

            pred_list.extend(preds_)
            true_onehot_list.extend(true_onehot)
            
            _, preds = torch.max(probs, 1) # preds = probs.max(dim=1)[1]
            correct = (preds == labels).sum()
            accuracy = correct / images.shape[0]
            test_accuracy += accuracy
        test_auc = roc_auc_score(true_onehot_list, pred_list)
    return test_loss, test_accuracy, test_auc

# %%
learning_rate = CFG['LEARNING_RATE']
criterion = nn.CrossEntropyLoss(reduction='sum')
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min", patience=CFG['SCHEDULER'], factor=0.1, verbose=True)

# %%
# 모델 저장 폴더 생성
import os
try:
    os.mkdir('model_saved')
except:
    pass

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

vali_acc=[]
vali_loss=[]

def train(model, epochs, criterion, optimizer):
    global vali_acc, vali_loss
    steps = 0
 
    # 1 에폭(epoch)당 반복수
    #iter_per_epoch = len(trainset) / batch_size  
    iter_per_epoch = len(train_loader) 
    print_every = iter_per_epoch
    best_auc = 0
    valid_auc = 0

    # for Early stopping
    min_loss = 1000
    trigger = 0
    patience = CFG['PATIENCE']

    # learning
    valid_loss = 0
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for images, labels in tqdm(iter(train_loader)):
            steps += 1
            images, labels = images.to(device), labels.to(device)

            
            optimizer.zero_grad()

            # 1. Forward (Loss 얻게됨)
            output = model.forward(images)
            loss = criterion(output, labels)

            # 2. Backward (Gradient가 오차역전파로 구해짐)
            loss.backward()

            # 3. Gradient Descent (Model parameter update) :  W <- W-lr*Gradient
            optimizer.step() 

            train_loss += loss.item() # 1 epoch 당 누적된 로스
            
            if steps % print_every == 0 : 
                 # 배치 정규화, 드롭아웃 이 적용될 경우 model.forward 연산이 training 때와 다르므로 반드시 설정
                model.eval()
                valid_loss, valid_accuracy, valid_auc = validation(model, vali_loader, criterion)
                
                vali_acc.append(valid_accuracy/len(vali_loader))
                vali_loss.append(valid_loss/len(vali_loader))

                writer.add_scalar("Loss/train", train_loss/len(train_loader), epoch)
                writer.add_scalar("Loss/test", valid_loss/len(vali_loader), epoch)
                writer.add_scalars("Loss/train and valid",
                                { "train" : train_loss/len(train_loader),
                                    "test" : valid_loss/len(vali_loader) }, epoch)
                writer.add_scalar("test_roc_auc", valid_auc, epoch)

                print("Epoch : {}/{}...".format(epoch+1, epochs),
                    " Train Loss : {:.3f}".format(train_loss/len(train_loader) ),
                    " Valid Loss : {:.3f}".format(valid_loss/len(vali_loader)),
                    " Valid Accuracy : {:.3f}".format(valid_accuracy/len(vali_loader)),
                    " Valid AUC_ROC :  {:.3f}".format(valid_auc))
                
                # Early stopping Start 
                if valid_loss > min_loss: 
                    trigger +=1
                    print("trigger :", trigger)
                    if trigger > patience: 
                        print("Early Stopping!!!")
                        print("Train step is finished!!")
                        writer.flush()
                        writer.close() 
                        return
                else: 
                    min_loss = valid_loss
                    trigger = 0
                
                # Early stopping End
                train_loss = 0
                model.train()
            # Best model 저장
            if valid_auc >= best_auc:
                torch.save(model.state_dict(), dir+"best_model_resnet.pth")
                best_auc = valid_auc
            

        # Learning Rate Scheduler 
        scheduler.step(valid_loss)
    writer.flush()
    writer.close()

# %%
train(model, CFG['EPOCHS'], criterion, optimizer)
# Out:
# 100%|█████████▉| 341/342 [09:57<00:02,  2.09s/it]
# Epoch : 1/150...  Train Loss : 0.847  Valid Loss : 1.120  Valid Accuracy : 0.919  Valid AUC_ROC :  0.949
# 100%|██████████| 342/342 [10:49<00:00,  1.90s/it]
# 100%|██████████| 342/342 [10:59<00:00,  1.93s/it]
# Epoch : 2/150...  Train Loss : 0.886  Valid Loss : 1.127  Valid Accuracy : 0.923  Valid AUC_ROC :  0.946
# trigger : 1
# 100%|██████████| 342/342 [06:58<00:00,  1.22s/it]
# Epoch : 3/150...  Train Loss : 0.799  Valid Loss : 1.464  Valid Accuracy : 0.860  Valid AUC_ROC :  0.939
# trigger : 2
# 100%|█████████▉| 341/342 [06:06<00:01,  1.08s/it]
# Epoch : 4/150...  Train Loss : 0.884  Valid Loss : 1.083  Valid Accuracy : 0.917  Valid AUC_ROC :  0.953
# 100%|██████████| 342/342 [06:56<00:00,  1.22s/it]
# 100%|█████████▉| 341/342 [09:57<00:01,  1.68s/it]
# Epoch : 5/150...  Train Loss : 0.795  Valid Loss : 1.011  Valid Accuracy : 0.925  Valid AUC_ROC :  0.957
# 100%|██████████| 342/342 [10:47<00:00,  1.89s/it]
# 100%|██████████| 342/342 [10:50<00:00,  1.90s/it]
# Epoch : 6/150...  Train Loss : 0.751  Valid Loss : 1.075  Valid Accuracy : 0.919  Valid AUC_ROC :  0.951
# trigger : 1
# 100%|██████████| 342/342 [06:55<00:00,  1.22s/it]
# Epoch : 7/150...  Train Loss : 0.794  Valid Loss : 1.197  Valid Accuracy : 0.914  Valid AUC_ROC :  0.956
# trigger : 2
# 100%|██████████| 342/342 [06:50<00:00,  1.20s/it]
# Epoch : 8/150...  Train Loss : 1.120  Valid Loss : 1.231  Valid Accuracy : 0.910  Valid AUC_ROC :  0.937
# trigger : 3
# 100%|██████████| 342/342 [06:50<00:00,  1.20s/it]
# Epoch : 9/150...  Train Loss : 0.804  Valid Loss : 1.109  Valid Accuracy : 0.919  Valid AUC_ROC :  0.946
# trigger : 4
# 100%|██████████| 342/342 [06:50<00:00,  1.20s/it]
# Epoch : 10/150...  Train Loss : 0.823  Valid Loss : 1.351  Valid Accuracy : 0.906  Valid AUC_ROC :  0.936
# trigger : 5
# 100%|██████████| 342/342 [06:50<00:00,  1.20s/it]
# Epoch : 11/150...  Train Loss : 0.821  Valid Loss : 1.076  Valid Accuracy : 0.930  Valid AUC_ROC :  0.944
# trigger : 6
# 100%|██████████| 342/342 [06:51<00:00,  1.20s/it]
# Epoch : 12/150...  Train Loss : 0.623  Valid Loss : 1.705  Valid Accuracy : 0.893  Valid AUC_ROC :  0.929
# trigger : 7
# Epoch 00012: reducing learning rate of group 0 to 1.0000e-05.
# 100%|██████████| 342/342 [06:51<00:00,  1.20s/it]
# Epoch : 13/150...  Train Loss : 0.808  Valid Loss : 1.096  Valid Accuracy : 0.921  Valid AUC_ROC :  0.952
# trigger : 8
# 100%|██████████| 342/342 [06:52<00:00,  1.21s/it]
# Epoch : 14/150...  Train Loss : 0.560  Valid Loss : 0.914  Valid Accuracy : 0.932  Valid AUC_ROC :  0.956
# 100%|██████████| 342/342 [06:52<00:00,  1.21s/it]
# Epoch : 15/150...  Train Loss : 0.535  Valid Loss : 0.905  Valid Accuracy : 0.930  Valid AUC_ROC :  0.954
# 100%|██████████| 342/342 [06:52<00:00,  1.21s/it]
# Epoch : 16/150...  Train Loss : 0.549  Valid Loss : 0.869  Valid Accuracy : 0.936  Valid AUC_ROC :  0.957
# 100%|██████████| 342/342 [06:52<00:00,  1.21s/it]
# Epoch : 17/150...  Train Loss : 0.536  Valid Loss : 0.898  Valid Accuracy : 0.941  Valid AUC_ROC :  0.957
# trigger : 1
# 100%|█████████▉| 341/342 [06:04<00:01,  1.10s/it]
# Epoch : 18/150...  Train Loss : 0.489  Valid Loss : 0.840  Valid Accuracy : 0.936  Valid AUC_ROC :  0.962
# 100%|██████████| 342/342 [06:55<00:00,  1.21s/it]
# 100%|██████████| 342/342 [10:44<00:00,  1.89s/it]
# Epoch : 19/150...  Train Loss : 0.439  Valid Loss : 0.901  Valid Accuracy : 0.932  Valid AUC_ROC :  0.954
# trigger : 1
# 100%|██████████| 342/342 [06:59<00:00,  1.23s/it]
# Epoch : 20/150...  Train Loss : 0.529  Valid Loss : 0.860  Valid Accuracy : 0.941  Valid AUC_ROC :  0.960
# trigger : 2
# 100%|██████████| 342/342 [06:58<00:00,  1.22s/it]
# Epoch : 21/150...  Train Loss : 0.449  Valid Loss : 0.887  Valid Accuracy : 0.939  Valid AUC_ROC :  0.954
# trigger : 3
# 100%|██████████| 342/342 [06:54<00:00,  1.21s/it]
# Epoch : 22/150...  Train Loss : 0.420  Valid Loss : 0.855  Valid Accuracy : 0.934  Valid AUC_ROC :  0.961
# trigger : 4
# 100%|██████████| 342/342 [06:54<00:00,  1.21s/it]
# Epoch : 23/150...  Train Loss : 0.454  Valid Loss : 0.918  Valid Accuracy : 0.932  Valid AUC_ROC :  0.955
# trigger : 5
# 100%|██████████| 342/342 [06:53<00:00,  1.21s/it]
# Epoch : 24/150...  Train Loss : 0.465  Valid Loss : 0.898  Valid Accuracy : 0.936  Valid AUC_ROC :  0.958
# trigger : 6
# 100%|██████████| 342/342 [06:48<00:00,  1.19s/it]
# Epoch : 25/150...  Train Loss : 0.384  Valid Loss : 0.909  Valid Accuracy : 0.936  Valid AUC_ROC :  0.954
# trigger : 7
# Epoch 00025: reducing learning rate of group 0 to 1.0000e-06.
# 100%|██████████| 342/342 [06:45<00:00,  1.19s/it]
# Epoch : 26/150...  Train Loss : 0.391  Valid Loss : 0.856  Valid Accuracy : 0.943  Valid AUC_ROC :  0.959
# trigger : 8
# 100%|██████████| 342/342 [06:49<00:00,  1.20s/it]
# Epoch : 27/150...  Train Loss : 0.401  Valid Loss : 0.857  Valid Accuracy : 0.936  Valid AUC_ROC :  0.958
# trigger : 9
# 100%|██████████| 342/342 [06:46<00:00,  1.19s/it]
# Epoch : 28/150...  Train Loss : 0.379  Valid Loss : 0.881  Valid Accuracy : 0.936  Valid AUC_ROC :  0.958
# trigger : 10
# 100%|██████████| 342/342 [06:44<00:00,  1.18s/it]
# Epoch : 29/150...  Train Loss : 0.425  Valid Loss : 0.893  Valid Accuracy : 0.936  Valid AUC_ROC :  0.955
# trigger : 11
# 100%|██████████| 342/342 [06:45<00:00,  1.18s/it]
# Epoch : 30/150...  Train Loss : 0.440  Valid Loss : 0.928  Valid Accuracy : 0.939  Valid AUC_ROC :  0.956
# trigger : 12
#  37%|███▋      | 127/342 [02:12<03:42,  1.04s/it]

# %%
train(model, CFG['EPOCHS'], criterion, optimizer)

# %% [markdown]
# # 모델 평가

# %%
def evaluate_v(model, testloader):
    test_accuracy = 0
    test_loss = 0
    true_onehot_list = []
    pred_list = []
    model.eval()
    with torch.no_grad(): # 예측에는 gradient가 필요 없음
        for images, labels in testloader: # 1 iteration마다 배치 단위로 image와 label을 가져옴
            images, labels = images.to(device), labels.to(device)
            # not Flatten!
            #images.resize_(images.shape[0], 784) # batch size x 784
            logits = model.forward(images) # 입력 : batch * height * width
            
            loss = criterion(logits, labels)
            test_loss += loss.item()

            true_onehot = torch.eye(4)[labels].cpu().numpy()
            preds_ = torch.softmax(logits.cpu(), dim=1).numpy()

            pred_list.extend(preds_)
            true_onehot_list.extend(true_onehot)

            probs = F.softmax(logits, dim=1)
            _, preds = torch.max(probs, 1) # preds = probs.max(dim=1)[1]

            correct = (preds == labels).sum()
            accuracy = correct / images.shape[0]
            test_accuracy += accuracy.item()

        test_auc = roc_auc_score(true_onehot_list, pred_list)
    print("Test Loss : ", test_loss/len(testloader))
    print("Accuracy : ", test_accuracy/len(testloader))
    print("AUC_ROC : ", test_auc)



def evaluate_t(model, testloader):
    test_accuracy = 0
    preds_test = np.zeros((len(test_img_path), 4))

    model.eval()
    with torch.no_grad(): # 예측에는 gradient가 필요 없음
        for i, images in enumerate(test_loader):
            images = images.to(device)
            outputs = model(images)
            # Target Prediction Probability
            probs = F.softmax(outputs.cpu(), dim=1).squeeze().numpy()
            preds_test[i*CFG['BATCH_SIZE']:(i+1)*CFG['BATCH_SIZE']] += probs

    return preds_test

# %%
# 마지막 학습결과를 저장 후 나중에 사용하기 원할 때
torch.save(model.state_dict(), dir+"last_checkpoint_resnet.pth")
state_dict = torch.load(dir+"last_checkpoint_resnet.pth") 
last_model = resnet101() # 이미 model에 마지막 학습결과가 있으나 last_model로 다시 불러옴
last_model.to(device)
last_model.load_state_dict(state_dict) # model과 parameter를 매치 시키는 작업
test_preds=evaluate_t(last_model, test_loader)

# %%
evaluate_v(last_model, vali_loader)

# %%
submission = pd.read_csv('./plant-pathology/sample_submission.csv')

# %%
submission_test = submission.copy()

# %%
submission_test[['healthy', 'multiple_diseases', 'rust', 'scab']] = test_preds

# %%
submission_test.to_csv('submission.csv', index=False)

# %%
# Test Accuracy 기준으로 가장 높을때의 모델 파라미터가 저장되어 있음
state_dict = torch.load(dir +"best_model_resnet.pth") 
best_model = resnet101()
best_model.to(device)
best_model.load_state_dict(state_dict)
test_preds=evaluate_t(best_model, test_loader)

# %%
submission_test2 = submission.copy()
submission_test2[['healthy', 'multiple_diseases', 'rust', 'scab']] = test_preds
submission_test2.to_csv('submission2.csv', index=False)

# %%
evaluate_v(best_model, vali_loader)
